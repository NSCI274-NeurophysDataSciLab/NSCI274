# %% [markdown]
# # Comparing Male and Female Hippocampus Responses to Natural Scenes and Natural Movies

# %% [markdown]
# ### Name: Deborah Agorua
#
#
# ### Date: 10/30/2022
#
#
# ### PID: 730397647
#
#
# ### Jupyter Notebook Number: 57539383

# %% [markdown]
# ## Purpose/Objective:
# Perform an ANOVA

# %% [markdown]
# ## Protocol:
# 1. Run an ANOVA test for each hippocampus region

# %% [markdown]
# ## Expected Results:
# ANOVA results

# %% [markdown]
# ### Installing AllenSDK into your local environment.

# %%
pip install allensdk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: allensdk in ./.local/lib/python3.9/site-packages (2.13.6)
# Requirement already satisfied: xarray<0.16.0 in ./.local/lib/python3.9/site-packages (from allensdk) (0.15.1)
# Requirement already satisfied: pynrrd<1.0.0,>=0.2.1 in ./.local/lib/python3.9/site-packages (from allensdk) (0.4.3)
# Requirement already satisfied: seaborn<1.0.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (0.11.2)
# Requirement already satisfied: jinja2>=3.0.0 in ./.local/lib/python3.9/site-packages (from allensdk) (3.1.2)
# Requirement already satisfied: statsmodels<=0.13.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (0.12.2)
# Requirement already satisfied: future<1.0.0,>=0.14.3 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (0.18.2)
# Requirement already satisfied: ndx-events<=0.2.0 in ./.local/lib/python3.9/site-packages (from allensdk) (0.2.0)
# Requirement already satisfied: tqdm>=4.27 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (4.62.3)
# Requirement already satisfied: sqlalchemy in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (1.4.22)
# Requirement already satisfied: numpy in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (1.20.3)
# Requirement already satisfied: glymur==0.8.19 in ./.local/lib/python3.9/site-packages (from allensdk) (0.8.19)
# Requirement already satisfied: simpleitk<3.0.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from allensdk) (2.1.1.2)
# Requirement already satisfied: requests-toolbelt<1.0.0 in ./.local/lib/python3.9/site-packages (from allensdk) (0.9.1)
# Requirement already satisfied: tables<3.7.0,>=3.6.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (3.6.1)
# Requirement already satisfied: psycopg2-binary<3.0.0,>=2.7 in ./.local/lib/python3.9/site-packages (from allensdk) (2.9.3)
# Requirement already satisfied: scikit-build<1.0.0 in ./.local/lib/python3.9/site-packages (from allensdk) (0.15.0)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (1.7.1)
# Requirement already satisfied: cachetools<5.0.0,>=4.2.1 in ./.local/lib/python3.9/site-packages (from allensdk) (4.2.4)
# Requirement already satisfied: scikit-image<0.17.0,>=0.14.0 in ./.local/lib/python3.9/site-packages (from allensdk) (0.16.2)
# Requirement already satisfied: boto3==1.17.21 in ./.local/lib/python3.9/site-packages (from allensdk) (1.17.21)
# Requirement already satisfied: pandas>=1.1.5 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (1.3.4)
# Requirement already satisfied: six<2.0.0,>=1.9.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (1.16.0)
# Requirement already satisfied: simplejson<4.0.0,>=3.10.0 in ./.local/lib/python3.9/site-packages (from allensdk) (3.17.6)
# Requirement already satisfied: pynwb in ./.local/lib/python3.9/site-packages (from allensdk) (2.1.0)
# Requirement already satisfied: aiohttp==3.7.4 in ./.local/lib/python3.9/site-packages (from allensdk) (3.7.4)
# Requirement already satisfied: argschema<4.0.0,>=3.0.1 in ./.local/lib/python3.9/site-packages (from allensdk) (3.0.4)
# Requirement already satisfied: hdmf>=2.5.8 in ./.local/lib/python3.9/site-packages (from allensdk) (3.4.0)
# Requirement already satisfied: requests<3.0.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (2.26.0)
# Requirement already satisfied: matplotlib<3.4.3,>=1.4.3 in ./.local/lib/python3.9/site-packages (from allensdk) (3.4.2)
# Requirement already satisfied: nest-asyncio in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (1.5.1)
# Requirement already satisfied: h5py in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from allensdk) (3.3.0)
# Requirement already satisfied: semver in ./.local/lib/python3.9/site-packages (from allensdk) (2.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.local/lib/python3.9/site-packages (from aiohttp==3.7.4->allensdk) (1.8.1)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in ./.local/lib/python3.9/site-packages (from aiohttp==3.7.4->allensdk) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from aiohttp==3.7.4->allensdk) (21.2.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in ./.local/lib/python3.9/site-packages (from aiohttp==3.7.4->allensdk) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from aiohttp==3.7.4->allensdk) (3.10.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.local/lib/python3.9/site-packages (from aiohttp==3.7.4->allensdk) (6.0.2)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in ./.local/lib/python3.9/site-packages (from boto3==1.17.21->allensdk) (0.3.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in ./.local/lib/python3.9/site-packages (from boto3==1.17.21->allensdk) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.21 in ./.local/lib/python3.9/site-packages (from boto3==1.17.21->allensdk) (1.20.112)
# Requirement already satisfied: setuptools in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from glymur==0.8.19->allensdk) (58.0.4)
# Requirement already satisfied: marshmallow<4.0,>=3.0.0 in ./.local/lib/python3.9/site-packages (from argschema<4.0.0,>=3.0.1->allensdk) (3.17.1)
# Requirement already satisfied: pyyaml in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from argschema<4.0.0,>=3.0.1->allensdk) (6.0)
# Requirement already satisfied: ruamel.yaml<1,>=0.16 in ./.local/lib/python3.9/site-packages (from hdmf>=2.5.8->allensdk) (0.17.21)
# Requirement already satisfied: jsonschema<5,>=2.6.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from hdmf>=2.5.8->allensdk) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.local/lib/python3.9/site-packages (from jinja2>=3.0.0->allensdk) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from matplotlib<3.4.3,>=1.4.3->allensdk) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from matplotlib<3.4.3,>=1.4.3->allensdk) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from matplotlib<3.4.3,>=1.4.3->allensdk) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from matplotlib<3.4.3,>=1.4.3->allensdk) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from matplotlib<3.4.3,>=1.4.3->allensdk) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from pandas>=1.1.5->allensdk) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from requests<3.0.0->allensdk) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from requests<3.0.0->allensdk) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from requests<3.0.0->allensdk) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from requests<3.0.0->allensdk) (3.2)
# Requirement already satisfied: packaging in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from scikit-build<1.0.0->allensdk) (21.0)
# Requirement already satisfied: wheel>=0.29.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from scikit-build<1.0.0->allensdk) (0.37.0)
# Requirement already satisfied: distro in ./.local/lib/python3.9/site-packages (from scikit-build<1.0.0->allensdk) (1.7.0)
# Requirement already satisfied: networkx>=2.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from scikit-image<0.17.0,>=0.14.0->allensdk) (2.6.3)
# Requirement already satisfied: PyWavelets>=0.4.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from scikit-image<0.17.0,>=0.14.0->allensdk) (1.1.1)
# Requirement already satisfied: imageio>=2.3.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from scikit-image<0.17.0,>=0.14.0->allensdk) (2.9.0)
# Requirement already satisfied: patsy>=0.5 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from statsmodels<=0.13.0->allensdk) (0.5.2)
# Requirement already satisfied: numexpr>=2.6.2 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from tables<3.7.0,>=3.6.0->allensdk) (2.7.3)
# Requirement already satisfied: greenlet!=0.4.17 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from sqlalchemy->allensdk) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages (from jsonschema<5,>=2.6.0->hdmf>=2.5.8->allensdk) (0.18.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in ./.local/lib/python3.9/site-packages (from ruamel.yaml<1,>=0.16->hdmf>=2.5.8->allensdk) (0.2.6)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Packages:

# %%
import os
import shutil
import allensdk
import pprint
from pathlib import Path

import numpy as np
import pandas as pd
import scipy.stats as st

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_context('notebook', font_scale=1.5, rc={'lines.markeredgewidth': 2})

# %% [markdown]
# ### If working with Visual Coding: Neuropixels Data use the following code block to import the cache object and point it to the data already downloaded and stored on LongLeaf.  Do not change this code.

# %%
#this code block should only be run if you are working with the neuropixels data
from allensdk.brain_observatory.ecephys.ecephys_project_cache import EcephysProjectCache

data_directory = '/overflow/NSCI274/projects/ecephysdata/' 

manifest_path = os.path.join(data_directory, "manifest.json")

cache = EcephysProjectCache.from_warehouse(manifest=manifest_path)

# %% [markdown]
# ### Import sessions data

# %%
data_directory = "/overflow/NSCI274/projects/ecephysdata/"

manifest_path = os.path.join(data_directory,"manifest.json")

cache = EcephysProjectCache.from_warehouse(manifest=manifest_path)

# %%
sessions = cache.get_session_table()

print('Total number of sessions: ' + str(len(sessions)))

sessions.head()
# Out:
# Total number of sessions: 58
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
# 719161530  2019-10-03T00:00:00Z    703279284  brain_observatory_1.1
# 721123822  2019-10-03T00:00:00Z    707296982  brain_observatory_1.1
# 732592105  2019-10-03T00:00:00Z    717038288  brain_observatory_1.1
# 737581020  2019-10-03T00:00:00Z    718643567  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 715093703        118.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 719161530        122.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 721123822        125.0   M  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 732592105        100.0   M                                            wt/wt
# 737581020        108.0   M                                            wt/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
# 719161530         755           2214            6
# 721123822         444           2229            6
# 732592105         824           1847            5
# 737581020         568           2218            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...
# 719161530  [TH, Eth, APN, POL, LP, DG, CA1, VISpm, nan, N...
# 721123822  [MB, SCig, PPT, NOT, DG, CA1, VISam, nan, LP, ...
# 732592105       [grey, VISpm, nan, VISp, VISl, VISal, VISrl]
# 737581020      [grey, VISmma, nan, VISpm, VISp, VISl, VISrl]

# %% [markdown]
# ### Discover the number of sessions for male mice and female mice

# %%
filtered_sessionsm = sessions[(sessions.sex == 'M') & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['DG' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]

print('Total number of male sessions: ' + str(len(filtered_sessionsm)))

filtered_sessionsm.head()
# Out:
# Total number of male sessions: 22
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
# 719161530  2019-10-03T00:00:00Z    703279284  brain_observatory_1.1
# 721123822  2019-10-03T00:00:00Z    707296982  brain_observatory_1.1
# 743475441  2019-10-03T00:00:00Z    722882755  brain_observatory_1.1
# 744228101  2019-10-03T00:00:00Z    719817805  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 715093703        118.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 719161530        122.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 721123822        125.0   M  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 743475441        121.0   M                                            wt/wt
# 744228101        122.0   M                                            wt/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
# 719161530         755           2214            6
# 721123822         444           2229            6
# 743475441         553           2225            6
# 744228101         659           2226            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...
# 719161530  [TH, Eth, APN, POL, LP, DG, CA1, VISpm, nan, N...
# 721123822  [MB, SCig, PPT, NOT, DG, CA1, VISam, nan, LP, ...
# 743475441  [LP, LGd, HPF, DG, CA3, CA1, VISrl, nan, PP, P...
# 744228101  [Eth, TH, LP, POL, APN, DG, CA1, VIS, nan, CA3...

# %%
filtered_sessionsm_ca1 = sessions[(sessions.sex == 'M') & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['CA1' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]

print('Total number of male sessions: ' + str(len(filtered_sessionsm_ca1)))

filtered_sessionsm_ca1.head()
# Out:
# Total number of male sessions: 22
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
# 719161530  2019-10-03T00:00:00Z    703279284  brain_observatory_1.1
# 721123822  2019-10-03T00:00:00Z    707296982  brain_observatory_1.1
# 743475441  2019-10-03T00:00:00Z    722882755  brain_observatory_1.1
# 744228101  2019-10-03T00:00:00Z    719817805  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 715093703        118.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 719161530        122.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 721123822        125.0   M  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 743475441        121.0   M                                            wt/wt
# 744228101        122.0   M                                            wt/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
# 719161530         755           2214            6
# 721123822         444           2229            6
# 743475441         553           2225            6
# 744228101         659           2226            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...
# 719161530  [TH, Eth, APN, POL, LP, DG, CA1, VISpm, nan, N...
# 721123822  [MB, SCig, PPT, NOT, DG, CA1, VISam, nan, LP, ...
# 743475441  [LP, LGd, HPF, DG, CA3, CA1, VISrl, nan, PP, P...
# 744228101  [Eth, TH, LP, POL, APN, DG, CA1, VIS, nan, CA3...

# %%
filtered_sessionsm_ca3 = sessions[(sessions.sex == 'M') & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['CA3' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]

print('Total number of CA3 male sessions: ' + str(len(filtered_sessionsm_ca1)))

filtered_sessionsm_ca1.head()
# Out:
# Total number of CA3 male sessions: 22
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
# 719161530  2019-10-03T00:00:00Z    703279284  brain_observatory_1.1
# 721123822  2019-10-03T00:00:00Z    707296982  brain_observatory_1.1
# 743475441  2019-10-03T00:00:00Z    722882755  brain_observatory_1.1
# 744228101  2019-10-03T00:00:00Z    719817805  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 715093703        118.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 719161530        122.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 721123822        125.0   M  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 743475441        121.0   M                                            wt/wt
# 744228101        122.0   M                                            wt/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
# 719161530         755           2214            6
# 721123822         444           2229            6
# 743475441         553           2225            6
# 744228101         659           2226            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...
# 719161530  [TH, Eth, APN, POL, LP, DG, CA1, VISpm, nan, N...
# 721123822  [MB, SCig, PPT, NOT, DG, CA1, VISam, nan, LP, ...
# 743475441  [LP, LGd, HPF, DG, CA3, CA1, VISrl, nan, PP, P...
# 744228101  [Eth, TH, LP, POL, APN, DG, CA1, VIS, nan, CA3...

# %%
# filtered_sessions_scenes = sessions[(session.stimulus_name == 'natural_scenes') & \
#                              (sessions.session_type == 'brain_observatory_1.1') & \
#                              (['DG' in acronyms for acronyms in 
#                                sessions.ecephys_structure_acronyms])]

# print('Total number of male sessions: ' + str(len(filtered_sessionsm)))

# filtered_sessionsm.head()

# %%
filtered_sessionsf = sessions[(sessions.sex == 'F') & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['DG' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]

print('Total number of DG female sessions: ' + str(len(filtered_sessionsf)))

filtered_sessionsf.head()
# Out:
# Total number of DG female sessions: 3
#                    published_at  specimen_id           session_type  \
# id
# 751348571  2019-10-03T00:00:00Z    732548380  brain_observatory_1.1
# 773418906  2019-10-03T00:00:00Z    757329624  brain_observatory_1.1
# 798911424  2019-10-03T00:00:00Z    775876828  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 751348571         93.0   F    Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 773418906        124.0   F  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 798911424        110.0   F    Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 751348571         859           2217            6
# 773418906         546           2232            6
# 798911424         825           2233            6
#
#                                   ecephys_structure_acronyms
# id
# 751348571  [grey, LGv, CA3, DG, CA1, VISl, nan, APN, POL,...
# 773418906  [PPT, NOT, SUB, ProS, CA1, VISam, nan, APN, DG...
# 798911424  [APN, TH, Eth, LP, DG, HPF, CA3, CA1, VISrl, n...

# %%
filtered_sessionsf_ca1 = sessions[(sessions.sex == 'F') & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['CA1' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]

print('Total number of CA1 female sessions: ' + str(len(filtered_sessionsf_ca1)))

filtered_sessionsf_ca1.head()
# Out:
# Total number of CA1 female sessions: 4
#                    published_at  specimen_id           session_type  \
# id
# 746083955  2019-10-03T00:00:00Z    726170935  brain_observatory_1.1
# 751348571  2019-10-03T00:00:00Z    732548380  brain_observatory_1.1
# 773418906  2019-10-03T00:00:00Z    757329624  brain_observatory_1.1
# 798911424  2019-10-03T00:00:00Z    775876828  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 746083955         98.0   F  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 751348571         93.0   F    Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 773418906        124.0   F  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 798911424        110.0   F    Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 746083955         582           2216            6
# 751348571         859           2217            6
# 773418906         546           2232            6
# 798911424         825           2233            6
#
#                                   ecephys_structure_acronyms
# id
# 746083955  [VPM, TH, LGd, CA3, CA2, CA1, VISal, nan, grey...
# 751348571  [grey, LGv, CA3, DG, CA1, VISl, nan, APN, POL,...
# 773418906  [PPT, NOT, SUB, ProS, CA1, VISam, nan, APN, DG...
# 798911424  [APN, TH, Eth, LP, DG, HPF, CA3, CA1, VISrl, n...

# %%
filtered_sessionsf_ca3 = sessions[(sessions.sex == 'F') & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['CA3' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]

print('Total number of CA3 female sessions: ' + str(len(filtered_sessionsf_ca1)))

filtered_sessionsf_ca3.head()
# Out:
# Total number of CA3 female sessions: 4
#                    published_at  specimen_id           session_type  \
# id
# 746083955  2019-10-03T00:00:00Z    726170935  brain_observatory_1.1
# 751348571  2019-10-03T00:00:00Z    732548380  brain_observatory_1.1
# 773418906  2019-10-03T00:00:00Z    757329624  brain_observatory_1.1
# 798911424  2019-10-03T00:00:00Z    775876828  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 746083955         98.0   F  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 751348571         93.0   F    Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 773418906        124.0   F  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 798911424        110.0   F    Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 746083955         582           2216            6
# 751348571         859           2217            6
# 773418906         546           2232            6
# 798911424         825           2233            6
#
#                                   ecephys_structure_acronyms
# id
# 746083955  [VPM, TH, LGd, CA3, CA2, CA1, VISal, nan, grey...
# 751348571  [grey, LGv, CA3, DG, CA1, VISl, nan, APN, POL,...
# 773418906  [PPT, NOT, SUB, ProS, CA1, VISam, nan, APN, DG...
# 798911424  [APN, TH, Eth, LP, DG, HPF, CA3, CA1, VISrl, n...

# %% [markdown]
# ### Create units table

# %%
session_idm = filtered_sessionsm.index.values[2]

sessionm = cache.get_session_data(session_idm)

session_idf = filtered_sessionsf.index.values[2]

#sessionf = cache.get_session_data(session_idf)
sessionf = cache.get_session_data(session_idf)

# %%
session_idm_ca1 = filtered_sessionsm_ca1.index.values[2]

sessionm_ca1 = cache.get_session_data(session_idm_ca1)

session_idf_ca1 = filtered_sessionsf_ca1.index.values[2]

#sessionf = cache.get_session_data(session_idf)
sessionf_ca1 = cache.get_session_data(session_idf_ca1)

# %%
session_idm_ca3 = filtered_sessionsm_ca3.index.values[2]

sessionm_ca3 = cache.get_session_data(session_idm_ca3)

session_idf_ca3 = filtered_sessionsf_ca3.index.values[2]

#sessionf = cache.get_session_data(session_idf)
sessionf_ca3 = cache.get_session_data(session_idf_ca3)

# %%
filtered_sessions_scenes = sessions[(sessionm.stimulus_names == 'natural_scenes') & \
                             (sessions.session_type == 'brain_observatory_1.1') & \
                             (['DG' in acronyms for acronyms in 
                               sessions.ecephys_structure_acronyms])]
filtered_sessions_scenes.head()
# Out:
# Empty DataFrame
# Columns: [published_at, specimen_id, session_type, age_in_days, sex, full_genotype, unit_count, channel_count, probe_count, ecephys_structure_acronyms]
# Index: []

# %%
unitsm = sessionm.units

print('Total number of male units: ' + str(len(unitsm)))
themlist=unitsm['ecephys_structure_acronym'].to_list()
resmlist=[*set(themlist)]
print(resmlist)
unitsm.head()
# Out:
# Total number of male units: 444
# ['CA3', 'POL', 'CA1', 'VISp', 'SCig', 'LGv', 'DG', 'VISam', 'LP', 'VISal', 'VIS', 'VISl', 'VISrl', 'APN', 'MB']
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 950907205           1.054721          101.262915          0.012123
# 950907524           0.558508          136.843200          0.002313
# 950907209           0.637890          114.131278          0.084063
# 950907526           0.576049           85.886190          0.024568
# 950907216           0.651440           79.630785          0.002750
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 950907205           1            250.13  5.252421    14.739577
# 950907524         154            279.40  5.439966     1.448536
# 950907209           3              0.00  3.246909     0.040263
# 950907526         155            532.46  5.347055     0.376838
# 950907216           6            262.20  5.657655     8.277175
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 950907205        0.005100          129.172458  0.002403  ...
# 950907524        0.000000           50.450187  0.004085  ...
# 950907209        0.000000           19.926951  0.023899  ...
# 950907526        0.000000           66.773857  0.000197  ...
# 950907216        0.007249           89.982684  0.002184  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 950907205                 313.0                         MB
# 950907524                 313.0                         MB
# 950907209                 313.0                         MB
# 950907526                 313.0                         MB
# 950907216                 313.0                         MB
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 950907205                             8456.0                         3144.0
# 950907524                             8447.0                         3127.0
# 950907209                             8447.0                         3127.0
# 950907526                             8433.0                         3102.0
# 950907216                             8419.0                         3077.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 950907205                     6920.0             probeA
# 950907524                     6924.0             probeA
# 950907209                     6924.0             probeA
# 950907526                     6929.0             probeA
# 950907216                     6934.0             probeA
#
#                           location  probe_sampling_rate  \
# unit_id
# 950907205  See electrode locations         29999.970785
# 950907524  See electrode locations         29999.970785
# 950907209  See electrode locations         29999.970785
# 950907526  See electrode locations         29999.970785
# 950907216  See electrode locations         29999.970785
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 950907205              1249.998783                True
# 950907524              1249.998783                True
# 950907209              1249.998783                True
# 950907526              1249.998783                True
# 950907216              1249.998783                True
#
# [5 rows x 40 columns]

# %%
unitsm_ca1 = sessionm_ca1.units

print('Total number of male units: ' + str(len(unitsm_ca1)))
themlistca1=unitsm_ca1['ecephys_structure_acronym'].to_list()
resmlistca1=[*set(themlistca1)]
print(resmlistca1)
unitsm_ca1.head()
# Out:
# Total number of male units: 444
# ['CA3', 'POL', 'CA1', 'VISp', 'SCig', 'LGv', 'DG', 'VISam', 'LP', 'VISal', 'VIS', 'VISl', 'VISrl', 'APN', 'MB']
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 950907205           1.054721          101.262915          0.012123
# 950907524           0.558508          136.843200          0.002313
# 950907209           0.637890          114.131278          0.084063
# 950907526           0.576049           85.886190          0.024568
# 950907216           0.651440           79.630785          0.002750
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 950907205           1            250.13  5.252421    14.739577
# 950907524         154            279.40  5.439966     1.448536
# 950907209           3              0.00  3.246909     0.040263
# 950907526         155            532.46  5.347055     0.376838
# 950907216           6            262.20  5.657655     8.277175
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 950907205        0.005100          129.172458  0.002403  ...
# 950907524        0.000000           50.450187  0.004085  ...
# 950907209        0.000000           19.926951  0.023899  ...
# 950907526        0.000000           66.773857  0.000197  ...
# 950907216        0.007249           89.982684  0.002184  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 950907205                 313.0                         MB
# 950907524                 313.0                         MB
# 950907209                 313.0                         MB
# 950907526                 313.0                         MB
# 950907216                 313.0                         MB
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 950907205                             8456.0                         3144.0
# 950907524                             8447.0                         3127.0
# 950907209                             8447.0                         3127.0
# 950907526                             8433.0                         3102.0
# 950907216                             8419.0                         3077.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 950907205                     6920.0             probeA
# 950907524                     6924.0             probeA
# 950907209                     6924.0             probeA
# 950907526                     6929.0             probeA
# 950907216                     6934.0             probeA
#
#                           location  probe_sampling_rate  \
# unit_id
# 950907205  See electrode locations         29999.970785
# 950907524  See electrode locations         29999.970785
# 950907209  See electrode locations         29999.970785
# 950907526  See electrode locations         29999.970785
# 950907216  See electrode locations         29999.970785
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 950907205              1249.998783                True
# 950907524              1249.998783                True
# 950907209              1249.998783                True
# 950907526              1249.998783                True
# 950907216              1249.998783                True
#
# [5 rows x 40 columns]

# %%
unitsm_ca3= sessionm_ca3.units

# %%
unitsf = sessionf.units

print('Total number of female units: ' + str(len(unitsf)))
thelist=unitsf['ecephys_structure_acronym'].to_list()
reslist=[*set(thelist)]
print(reslist)
unitsf.head(100)
# Out:
# Total number of female units: 825
# ['CA3', 'NOT', 'CA1', 'VISp', 'TH', 'LGv', 'DG', 'SUB', 'VISam', 'CA2', 'LP', 'VISal', 'Eth', 'VISl', 'VISrl', 'APN', 'MB', 'ProS']
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 951088679           0.620607           82.147455          0.023654
# 951088664           0.587044           78.399165          0.001739
# 951088734           0.560996          187.504005          0.001249
# 951088721           0.474457          196.741545          0.000059
# 951088862           0.534674           92.125020          0.089901
# ...                      ...                 ...               ...
# 951092912           0.343048           74.986080          0.015427
# 951094783           0.062807          109.564845          0.001595
# 951093080           0.576623          107.448315          0.029407
# 951093069           0.389044          138.448440          0.030320
# 951093048           0.272898          130.594620          0.035557
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 951088679           1            480.97  2.575648     7.429131
# 951088664           0            427.07  3.085334     6.843864
# 951088734           5            311.01  5.152564     1.418476
# 951088721           4            355.17  4.295014    11.517381
# 951088862          16            239.50  4.043348    19.953126
# ...               ...               ...       ...          ...
# 951092912         306            331.55  2.625901     3.275160
# 951094783         443            193.46  3.262489     5.224870
# 951093080         320             76.37  4.238720    30.788574
# 951093069         319            187.19  2.955943     9.783231
# 951093048         317            212.37  3.077729    11.829415
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 951088679        0.053350           51.364291  0.028062  ...
# 951088664        0.033732           40.358293  0.051513  ...
# 951088734        0.356931           56.950961  0.001292  ...
# 951088721        0.000271           58.358552  0.020218  ...
# 951088862        0.013619           79.934237  0.011335  ...
# ...                   ...                 ...       ...  ...
# 951092912        0.050214           51.855880  0.003558  ...
# 951094783        0.040776           59.900239  0.002028  ...
# 951093080        0.004470          106.205546  0.000916  ...
# 951093069        0.063780           51.352051  0.015420  ...
# 951093048        0.190660           61.299544  0.010579  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 951088679                 215.0                        APN
# 951088664                 215.0                        APN
# 951088734                 215.0                        APN
# 951088721                 215.0                        APN
# 951088862                 215.0                        APN
# ...                         ...                        ...
# 951092912                 394.0                      VISam
# 951094783                 394.0                      VISam
# 951093080                 394.0                      VISam
# 951093069                 394.0                      VISam
# 951093048                 394.0                      VISam
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 951088679                             8328.0                         3018.0
# 951088664                             8328.0                         3018.0
# 951088734                             8316.0                         2988.0
# 951088721                             8316.0                         2988.0
# 951088862                             8304.0                         2958.0
# ...                                      ...                            ...
# 951092912                             7687.0                          819.0
# 951094783                             7682.0                          801.0
# 951093080                             7682.0                          801.0
# 951093069                             7682.0                          801.0
# 951093048                             7682.0                          801.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 951088679                     7095.0             probeA
# 951088664                     7095.0             probeA
# 951088734                     7099.0             probeA
# 951088721                     7099.0             probeA
# 951088862                     7103.0             probeA
# ...                              ...                ...
# 951092912                     7500.0             probeA
# 951094783                     7503.0             probeA
# 951093080                     7503.0             probeA
# 951093069                     7503.0             probeA
# 951093048                     7503.0             probeA
#
#                           location  probe_sampling_rate  \
# unit_id
# 951088679  See electrode locations         29999.965974
# 951088664  See electrode locations         29999.965974
# 951088734  See electrode locations         29999.965974
# 951088721  See electrode locations         29999.965974
# 951088862  See electrode locations         29999.965974
# ...                            ...                  ...
# 951092912  See electrode locations         29999.965974
# 951094783  See electrode locations         29999.965974
# 951093080  See electrode locations         29999.965974
# 951093069  See electrode locations         29999.965974
# 951093048  See electrode locations         29999.965974
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 951088679              1249.998582                True
# 951088664              1249.998582                True
# 951088734              1249.998582                True
# 951088721              1249.998582                True
# 951088862              1249.998582                True
# ...                            ...                 ...
# 951092912              1249.998582                True
# 951094783              1249.998582                True
# 951093080              1249.998582                True
# 951093069              1249.998582                True
# 951093048              1249.998582                True
#
# [100 rows x 40 columns]

# %%
unitsf_ca1= sessionf_ca1.units

print('Total number of female units: ' + str(len(unitsf_ca1)))
thelistca1=unitsf_ca1['ecephys_structure_acronym'].to_list()
reslistca1=[*set(thelistca1)]
print(reslistca1)
unitsf_ca1.head(100)
# Out:
# Total number of female units: 546
# ['CA3', 'NOT', 'CA1', 'VISp', 'TH', 'VISmmp', 'DG', 'SUB', 'VISam', 'MGd', 'VISal', 'VISrl', 'MGv', 'APN', 'MB', 'ProS']
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 951781164           0.397729           74.728680          0.080107
# 951781179           0.404661           95.422080          0.011366
# 951781341           0.594550           42.931785          0.001880
# 951781346           0.338191          107.153280          0.000154
# 951781375           0.577122          105.278550          0.001077
# ...                      ...                 ...               ...
# 951785333           0.622722           87.587175          0.093573
# 951785385           0.463898           27.936870          0.006592
# 951785427           0.495986           39.382395          0.000254
# 951785493           0.785188           32.272500          0.095647
# 951785584           0.479723          192.133305          0.000747
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 951781164           6            102.08  3.184190    14.848563
# 951781179           9             77.17  4.840396    11.982257
# 951781341          48            315.04  2.944735     4.698033
# 951781346          49            144.72  4.099752     7.144577
# 951781375          56            159.15  4.255690    11.999290
# ...               ...               ...       ...          ...
# 951785333          80            109.07  3.541663    19.480415
# 951785385          91            320.20  2.567400     4.526989
# 951785427         100            191.93  3.394125     2.363741
# 951785493         113            219.42  2.267509     4.868360
# 951785584         132            111.08  3.945473     7.782070
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 951781164        0.107623           63.568084  0.036502  ...
# 951781179        0.049019           75.035952  0.008291  ...
# 951781341        0.031364           86.322527  0.008108  ...
# 951781346        0.000000           74.737358  0.012747  ...
# 951781375        0.053956           61.066084  0.036021  ...
# ...                   ...                 ...       ...  ...
# 951785333        0.079757           62.424747  0.030794  ...
# 951785385        0.210188           45.361948  0.088020  ...
# 951785427        0.082598           50.542769  0.016098  ...
# 951785493        0.136302           37.589451  0.087179  ...
# 951785584        0.001270           89.412808  0.000276  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 951781164           484682470.0                       ProS
# 951781179                 382.0                        CA1
# 951781341                 394.0                      VISam
# 951781346                 394.0                      VISam
# 951781375                 394.0                      VISam
# ...                         ...                        ...
# 951785333                 502.0                        SUB
# 951785385                 385.0                       VISp
# 951785427                 385.0                       VISp
# 951785493                 385.0                       VISp
# 951785584                 385.0                       VISp
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 951781164                             8017.0                         1857.0
# 951781179                             8010.0                         1824.0
# 951781341                             7814.0                          890.0
# 951781346                             7807.0                          857.0
# 951781375                             7801.0                          832.0
# ...                                      ...                            ...
# 951785333                             8713.0                         2092.0
# 951785385                             8933.0                         1485.0
# 951785427                             8957.0                         1415.0
# 951785493                             8990.0                         1317.0
# 951785584                             9022.0                         1219.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 951781164                     7179.0             probeA
# 951781179                     7199.0             probeA
# 951781341                     7491.0             probeA
# 951781346                     7490.0             probeA
# 951781375                     7489.0             probeA
# ...                              ...                ...
# 951785333                     7827.0             probeC
# 951785385                     7995.0             probeC
# 951785427                     8001.0             probeC
# 951785493                     8008.0             probeC
# 951785584                     8012.0             probeC
#
#                           location  probe_sampling_rate  \
# unit_id
# 951781164  See electrode locations         29999.964439
# 951781179  See electrode locations         29999.964439
# 951781341  See electrode locations         29999.964439
# 951781346  See electrode locations         29999.964439
# 951781375  See electrode locations         29999.964439
# ...                            ...                  ...
# 951785333  See electrode locations         29999.995177
# 951785385  See electrode locations         29999.995177
# 951785427  See electrode locations         29999.995177
# 951785493  See electrode locations         29999.995177
# 951785584  See electrode locations         29999.995177
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 951781164              1249.998518                True
# 951781179              1249.998518                True
# 951781341              1249.998518                True
# 951781346              1249.998518                True
# 951781375              1249.998518                True
# ...                            ...                 ...
# 951785333              1249.999799                True
# 951785385              1249.999799                True
# 951785427              1249.999799                True
# 951785493              1249.999799                True
# 951785584              1249.999799                True
#
# [100 rows x 40 columns]

# %%
unitsf_ca3= sessionf_ca3.units

# %% [markdown]
# ### Filter units for Hippocampus Areas

# %%
DG_unitsm = unitsm[(unitsm.ecephys_structure_acronym == 'DG')]

print('Total number of male DG units: ' + str(len(DG_unitsm)))

DG_unitsm.head()
# Out:
# Total number of male DG units: 41
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 950907256           8.229653           95.517010          0.036145
# 950907719           0.502406          236.327130          0.000141
# 950907721           1.413915           91.812045          0.020535
# 950907717           0.271389          135.051930          0.001925
# 950907733           0.326786          110.713395          0.097751
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 950907256          24              0.00       NaN     0.060853
# 950907719          61             61.46  6.647542    19.238828
# 950907721          62            557.58  5.496564     7.212420
# 950907717          60            105.04  5.201824     3.694890
# 950907733          68            250.69  3.088837     5.344538
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 950907256        0.000000                 NaN       NaN  ...
# 950907719        0.016309          116.666580  0.001909  ...
# 950907721        0.008813           68.094419  0.003849  ...
# 950907717        0.039178           51.061316  0.027779  ...
# 950907733        0.120377           48.654929  0.032234  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 950907256                 726.0                         DG
# 950907719                 726.0                         DG
# 950907721                 726.0                         DG
# 950907717                 726.0                         DG
# 950907733                 726.0                         DG
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 950907256                             7988.0                         2274.0
# 950907719                             7567.0                         2175.0
# 950907721                             7571.0                         2144.0
# 950907717                             7571.0                         2144.0
# 950907733                             7575.0                         2103.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 950907256                     7154.0             probeA
# 950907719                     7376.0             probeB
# 950907721                     7379.0             probeB
# 950907717                     7379.0             probeB
# 950907733                     7383.0             probeB
#
#                           location  probe_sampling_rate  \
# unit_id
# 950907256  See electrode locations         29999.970785
# 950907719  See electrode locations         29999.923119
# 950907721  See electrode locations         29999.923119
# 950907717  See electrode locations         29999.923119
# 950907733  See electrode locations         29999.923119
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 950907256              1249.998783                True
# 950907719              1249.996797                True
# 950907721              1249.996797                True
# 950907717              1249.996797                True
# 950907733              1249.996797                True
#
# [5 rows x 40 columns]

# %%
DG_unitsf = unitsf[(unitsf.ecephys_structure_acronym == 'DG')]

print('Total number of female DG units: ' + str(len(DG_unitsf)))

DG_unitsf.head()
# Out:
# Total number of female DG units: 31
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 951090214           0.585876          112.724820          0.000105
# 951099104           2.118498           44.899725          0.063431
# 951095747           0.534207          154.266645          0.000431
# 951095759           0.261311          110.880510          0.001318
# 951095847           0.327950           34.730475          0.056136
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 951090214         105             73.01  6.211980    10.497929
# 951099104         302            266.39  3.514698    10.437201
# 951095747          62             65.84  4.256822     3.500400
# 951095759          64            102.72  5.066305     1.408227
# 951095847          69            108.71  2.694005     0.130964
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 951090214        0.028347           71.667279  0.004208  ...
# 951099104        0.007911           91.509599  0.004821  ...
# 951095747        0.000000           71.319775  0.008970  ...
# 951095759        0.000000           74.749922  0.000563  ...
# 951095847        0.000000           33.023656  0.016339  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 951090214                 726.0                         DG
# 951099104                 726.0                         DG
# 951095747                 726.0                         DG
# 951095759                 726.0                         DG
# 951095847                 726.0                         DG
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 951090214                             8019.0                         2162.0
# 951099104                             7747.0                         2334.0
# 951095747                             7747.0                         2334.0
# 951095759                             7750.0                         2312.0
# 951095847                             7754.0                         2282.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 951090214                     7291.0             probeA
# 951099104                     7452.0             probeB
# 951095747                     7452.0             probeB
# 951095759                     7451.0             probeB
# 951095847                     7449.0             probeB
#
#                           location  probe_sampling_rate  \
# unit_id
# 951090214  See electrode locations         29999.965974
# 951099104  See electrode locations         29999.917201
# 951095747  See electrode locations         29999.917201
# 951095759  See electrode locations         29999.917201
# 951095847  See electrode locations         29999.917201
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 951090214              1249.998582                True
# 951099104              1249.996550                True
# 951095747              1249.996550                True
# 951095759              1249.996550                True
# 951095847              1249.996550                True
#
# [5 rows x 40 columns]

# %%
CA1_unitsm = unitsm_ca1[(unitsm.ecephys_structure_acronym == 'CA1')]

print('Total number of male CA1 units: ' + str(len(CA1_unitsm)))

CA1_unitsm.head()
# Out:
# Total number of male CA1 units: 71
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 950907546           0.244961          122.157165          0.000854
# 950907296           0.304593           72.153510          0.033786
# 950907552           0.269583           90.767235          0.021036
# 950907301           0.425438          179.623275          0.000147
# 950907306           0.346616           90.277590          0.014060
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 950907546         165            127.42  4.346751     4.082628
# 950907296          43            158.56  4.418858     4.882172
# 950907552         168            143.71  4.718096     4.488108
# 950907301          45             84.29  7.952308    10.390707
# 950907306          47             91.75  3.999452     7.578033
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 950907546        0.082517           58.423581  0.011486  ...
# 950907296        0.309350           66.664742  0.002773  ...
# 950907552        0.434338           71.190553  0.001355  ...
# 950907301        0.000000          124.364300  0.000006  ...
# 950907306        0.304699           62.652103  0.021101  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 950907546                 382.0                        CA1
# 950907296                 382.0                        CA1
# 950907552                 382.0                        CA1
# 950907301                 382.0                        CA1
# 950907306                 382.0                        CA1
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 950907546                             7698.0                         1633.0
# 950907296                             7690.0                         1614.0
# 950907552                             7682.0                         1595.0
# 950907301                             7682.0                         1595.0
# 950907306                             7666.0                         1557.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 950907546                     7510.0             probeA
# 950907296                     7523.0             probeA
# 950907552                     7537.0             probeA
# 950907301                     7537.0             probeA
# 950907306                     7564.0             probeA
#
#                           location  probe_sampling_rate  \
# unit_id
# 950907546  See electrode locations         29999.970785
# 950907296  See electrode locations         29999.970785
# 950907552  See electrode locations         29999.970785
# 950907301  See electrode locations         29999.970785
# 950907306  See electrode locations         29999.970785
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 950907546              1249.998783                True
# 950907296              1249.998783                True
# 950907552              1249.998783                True
# 950907301              1249.998783                True
# 950907306              1249.998783                True
#
# [5 rows x 40 columns]

# %%
CA1_unitsf = unitsf_ca1[(unitsf_ca1.ecephys_structure_acronym == 'CA1')]

print('Total number of female CA1 units: ' + str(len(CA1_unitsf)))

CA1_unitsf.head()
# Out:
# Total number of female CA1 units: 72
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 951781179           0.404661           95.422080          0.011366
# 951779435           0.462240          169.897650          0.000269
# 951779456           0.394235          111.949305          0.003782
# 951779469           0.212392           63.219585          0.080877
# 951779510           0.288704          153.110685          0.000301
#
#            cluster_id  cumulative_drift    d_prime  firing_rate  \
# unit_id
# 951781179           9             77.17   4.840396    11.982257
# 951779435          51             43.15   7.119629     8.374772
# 951779456          55             69.59   5.992602     5.857313
# 951779469          57            130.82   5.095083     7.187714
# 951779510          65             59.07  10.259920     4.912612
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 951781179        0.049019           75.035952  0.008291  ...
# 951779435        0.000548           92.099760  0.001167  ...
# 951779456        0.015694           80.163813  0.003619  ...
# 951779469        0.074440           53.984054  0.017591  ...
# 951779510        0.001594           95.394609  0.000003  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 951781179                 382.0                        CA1
# 951779435                 382.0                        CA1
# 951779456                 382.0                        CA1
# 951779469                 382.0                        CA1
# 951779510                 382.0                        CA1
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 951781179                             8010.0                         1824.0
# 951779435                             8110.0                         3283.0
# 951779456                             8129.0                         3256.0
# 951779469                             8135.0                         3247.0
# 951779510                             8193.0                         3173.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 951781179                     7199.0             probeA
# 951779435                     9130.0             probeD
# 951779456                     9158.0             probeD
# 951779469                     9167.0             probeD
# 951779510                     9248.0             probeD
#
#                           location  probe_sampling_rate  \
# unit_id
# 951781179  See electrode locations         29999.964439
# 951779435  See electrode locations         29999.917865
# 951779456  See electrode locations         29999.917865
# 951779469  See electrode locations         29999.917865
# 951779510  See electrode locations         29999.917865
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 951781179              1249.998518                True
# 951779435              1249.996578                True
# 951779456              1249.996578                True
# 951779469              1249.996578                True
# 951779510              1249.996578                True
#
# [5 rows x 40 columns]

# %%
CA3_unitsm = unitsm_ca3[(unitsm_ca3.ecephys_structure_acronym == 'CA3')]

print('Total number of male CA3 units: ' + str(len(CA3_unitsm)))

CA3_unitsm.head()
# Out:
# Total number of male CA3 units: 10
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 950909583           0.410678          116.500800          0.032153
# 950909164           0.812153          118.097460          0.012017
# 950909160           0.661843          121.816890          0.043753
# 950911151           0.355969          150.825870          0.078970
# 950910006           0.377384          168.359685          0.020772
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 950909583         270            280.39  5.261019     6.622643
# 950909164          65            250.94  3.459251    13.927610
# 950909160          62            273.57  2.471769     5.058720
# 950911151         298            195.69  2.474091     1.081448
# 950910006          73            154.47  2.932607     5.841432
#
#            isi_violations  isolation_distance   L_ratio  ...  \
# unit_id                                                  ...
# 950909583        0.006098           59.768920  0.013978  ...
# 950909164        0.083509           56.290464  0.050416  ...
# 950909160        0.182137           35.275256  0.116370  ...
# 950911151        0.297752           49.131256  0.008799  ...
# 950910006        0.055563           83.053982  0.001869  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 950909583                 463.0                        CA3
# 950909164                 463.0                        CA3
# 950909160                 463.0                        CA3
# 950911151                 463.0                        CA3
# 950910006                 463.0                        CA3
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 950909583                             7927.0                         3370.0
# 950909164                             7944.0                         3325.0
# 950909160                             7944.0                         3325.0
# 950911151                             7812.0                         2800.0
# 950910006                             7812.0                         2800.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 950909583                     8666.0             probeD
# 950909164                     8687.0             probeD
# 950909160                     8687.0             probeD
# 950911151                     7979.0             probeE
# 950910006                     7979.0             probeE
#
#                           location  probe_sampling_rate  \
# unit_id
# 950909583  See electrode locations         29999.923530
# 950909164  See electrode locations         29999.923530
# 950909160  See electrode locations         29999.923530
# 950911151  See electrode locations         30000.003698
# 950910006  See electrode locations         30000.003698
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 950909583              1249.996814                True
# 950909164              1249.996814                True
# 950909160              1249.996814                True
# 950911151              1250.000154                True
# 950910006              1250.000154                True
#
# [5 rows x 40 columns]

# %%
CA3_unitsf = unitsf_ca3[(unitsf_ca3.ecephys_structure_acronym == 'CA3')]

print('Total number of female CA3 units: ' + str(len(CA3_unitsf)))

CA3_unitsf.head()
# Out:
# Total number of female CA3 units: 15
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# unit_id
# 951779253           0.229383          173.483895          0.012443
# 951779308           0.469803          226.081440          0.000215
# 951779304           0.467282          151.722285          0.009529
# 951779358           0.513716          166.787790          0.000180
# 951779349           0.339376          109.805475          0.000617
#
#            cluster_id  cumulative_drift   d_prime  firing_rate  \
# unit_id
# 951779253          18            253.24  3.374577     2.296855
# 951779308          28             73.95  7.151648    35.985151
# 951779304          27            303.73  4.603104     3.107346
# 951779358          37            126.60  7.221077    13.758965
# 951779349          35             83.33  5.661848    10.752584
#
#            isi_violations  isolation_distance       L_ratio  ...  \
# unit_id                                                      ...
# 951779253        0.284307           50.025363  6.051228e-03  ...
# 951779308        0.003297          115.967898  1.355759e-05  ...
# 951779304        0.306692           50.044596  8.160804e-03  ...
# 951779358        0.003047          132.393888  3.005030e-07  ...
# 951779349        0.002994          127.836394  5.733434e-08  ...
#
#            ecephys_structure_id  ecephys_structure_acronym  \
# unit_id
# 951779253                 463.0                        CA3
# 951779308                 463.0                        CA3
# 951779304                 463.0                        CA3
# 951779358                 463.0                        CA3
# 951779349                 463.0                        CA3
#
#            anterior_posterior_ccf_coordinate  dorsal_ventral_ccf_coordinate  \
# unit_id
# 951779253                             8028.0                         3415.0
# 951779308                             8043.0                         3387.0
# 951779304                             8043.0                         3387.0
# 951779358                             8056.0                         3366.0
# 951779349                             8053.0                         3371.0
#
#            left_right_ccf_coordinate  probe_description  \
# unit_id
# 951779253                     9006.0             probeD
# 951779308                     9030.0             probeD
# 951779304                     9030.0             probeD
# 951779358                     9050.0             probeD
# 951779349                     9045.0             probeD
#
#                           location  probe_sampling_rate  \
# unit_id
# 951779253  See electrode locations         29999.917865
# 951779308  See electrode locations         29999.917865
# 951779304  See electrode locations         29999.917865
# 951779358  See electrode locations         29999.917865
# 951779349  See electrode locations         29999.917865
#
#            probe_lfp_sampling_rate  probe_has_lfp_data
# unit_id
# 951779253              1249.996578                True
# 951779308              1249.996578                True
# 951779304              1249.996578                True
# 951779358              1249.996578                True
# 951779349              1249.996578                True
#
# [5 rows x 40 columns]

# %%
presentation_table = sessionm.stimulus_presentations[sessionm.stimulus_presentations.stimulus_name == 'natural_scenes']

presentation_table.head()
# Out:
#                          color contrast  frame orientation phase  size  \
# stimulus_presentation_id
# 51353                     null     null   92.0        null  null  null
# 51354                     null     null  114.0        null  null  null
# 51355                     null     null  114.0        null  null  null
# 51356                     null     null    0.0        null  null  null
# 51357                     null     null   37.0        null  null  null
#
#                          spatial_frequency   start_time stimulus_block  \
# stimulus_presentation_id
# 51353                                 null  5905.128132            9.0
# 51354                                 null  5905.378346            9.0
# 51355                                 null  5905.628560            9.0
# 51356                                 null  5905.878774            9.0
# 51357                                 null  5906.128988            9.0
#
#                            stimulus_name    stop_time temporal_frequency  \
# stimulus_presentation_id
# 51353                     natural_scenes  5905.378346               null
# 51354                     natural_scenes  5905.628560               null
# 51355                     natural_scenes  5905.878774               null
# 51356                     natural_scenes  5906.128988               null
# 51357                     natural_scenes  5906.379197               null
#
#                          x_position y_position  duration  \
# stimulus_presentation_id
# 51353                          null       null  0.250214
# 51354                          null       null  0.250214
# 51355                          null       null  0.250214
# 51356                          null       null  0.250214
# 51357                          null       null  0.250208
#
#                           stimulus_condition_id
# stimulus_presentation_id
# 51353                                      4908
# 51354                                      4909
# 51355                                      4909
# 51356                                      4910
# 51357                                      4911

# %%
presentation_table = sessionm.stimulus_presentations[sessionm.stimulus_presentations.stimulus_name == 'natural_movie_one']

presentation_table.head()
# Out:
#                          color contrast frame orientation phase  \
# stimulus_presentation_id
# 22000                     null      1.0   0.0         0.0  null
# 22001                     null      1.0   1.0         0.0  null
# 22002                     null      1.0   2.0         0.0  null
# 22003                     null      1.0   3.0         0.0  null
# 22004                     null      1.0   4.0         0.0  null
#
#                                       size spatial_frequency   start_time  \
# stimulus_presentation_id
# 22000                     [1920.0, 1080.0]              null  2848.575812
# 22001                     [1920.0, 1080.0]              null  2848.609173
# 22002                     [1920.0, 1080.0]              null  2848.642533
# 22003                     [1920.0, 1080.0]              null  2848.675894
# 22004                     [1920.0, 1080.0]              null  2848.709254
#
#                          stimulus_block      stimulus_name    stop_time  \
# stimulus_presentation_id
# 22000                               4.0  natural_movie_one  2848.609173
# 22001                               4.0  natural_movie_one  2848.642533
# 22002                               4.0  natural_movie_one  2848.675894
# 22003                               4.0  natural_movie_one  2848.709254
# 22004                               4.0  natural_movie_one  2848.742615
#
#                          temporal_frequency x_position y_position  duration  \
# stimulus_presentation_id
# 22000                                  null       null       null  0.033361
# 22001                                  null       null       null  0.033361
# 22002                                  null       null       null  0.033361
# 22003                                  null       null       null  0.033361
# 22004                                  null       null       null  0.033361
#
#                           stimulus_condition_id
# stimulus_presentation_id
# 22000                                      3887
# 22001                                      3888
# 22002                                      3889
# 22003                                      3890
# 22004                                      3891

# %%
presentation_table = sessionm.stimulus_presentations[sessionm.stimulus_presentations.stimulus_name == 'natural_movie_three']

presentation_table.head()
# Out:
#                          color contrast frame orientation phase  \
# stimulus_presentation_id
# 3999                      null      1.0   0.0         0.0  null
# 4000                      null      1.0   1.0         0.0  null
# 4001                      null      1.0   2.0         0.0  null
# 4002                      null      1.0   3.0         0.0  null
# 4003                      null      1.0   4.0         0.0  null
#
#                                       size spatial_frequency   start_time  \
# stimulus_presentation_id
# 3999                      [1920.0, 1080.0]              null  2218.049252
# 4000                      [1920.0, 1080.0]              null  2218.082613
# 4001                      [1920.0, 1080.0]              null  2218.115975
# 4002                      [1920.0, 1080.0]              null  2218.149336
# 4003                      [1920.0, 1080.0]              null  2218.182697
#
#                          stimulus_block        stimulus_name    stop_time  \
# stimulus_presentation_id
# 3999                                3.0  natural_movie_three  2218.082613
# 4000                                3.0  natural_movie_three  2218.115975
# 4001                                3.0  natural_movie_three  2218.149336
# 4002                                3.0  natural_movie_three  2218.182697
# 4003                                3.0  natural_movie_three  2218.216058
#
#                          temporal_frequency x_position y_position  duration  \
# stimulus_presentation_id
# 3999                                   null       null       null  0.033361
# 4000                                   null       null       null  0.033361
# 4001                                   null       null       null  0.033361
# 4002                                   null       null       null  0.033361
# 4003                                   null       null       null  0.033361
#
#                           stimulus_condition_id
# stimulus_presentation_id
# 3999                                        287
# 4000                                        288
# 4001                                        289
# 4002                                        290
# 4003                                        291

# %% [markdown]
# ### Filter spike data by sex for natural scenes and natural movies and calculate spike mean averages

# %%
natural_scenes_presentation_ids = sessionm.stimulus_presentations.loc[
    (sessionm.stimulus_presentations['stimulus_name'] == 'natural_scenes')
].index.values

statsm = sessionm.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=DG_unitsm.index.values
)

# display the parameters associated with each condition
statsm = pd.merge(statsm, sessionm.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Male Dentate Gyrus spike data in response to natural scenes')
statsm.head()
# Out:
# Male Dentate Gyrus spike data in response to natural scenes
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 950907256 4908                             1                           50
# 950907717 4908                            45                           50
# 950907719 4908                           225                           50
# 950907721 4908                            84                           50
# 950907727 4908                            93                           50
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 950907256 4908                         0.02   0.141421   0.020000  null
# 950907717 4908                         0.90   1.281740   0.181265  null
# 950907719 4908                         4.50   4.929089   0.697078  null
# 950907721 4908                         1.68   2.253704   0.318722  null
# 950907727 4908                         1.86   2.649682   0.374722  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 950907256 4908                      null  92.0  null    null        null
# 950907717 4908                      null  92.0  null    null        null
# 950907719 4908                      null  92.0  null    null        null
# 950907721 4908                      null  92.0  null    null        null
# 950907727 4908                      null  92.0  null    null        null
#
#                                 phase  size spatial_frequency   stimulus_name  \
# unit_id   stimulus_condition_id
# 950907256 4908                   null  null              null  natural_scenes
# 950907717 4908                   null  null              null  natural_scenes
# 950907719 4908                   null  null              null  natural_scenes
# 950907721 4908                   null  null              null  natural_scenes
# 950907727 4908                   null  null              null  natural_scenes
#
#                                 temporal_frequency units x_position  \
# unit_id   stimulus_condition_id
# 950907256 4908                                null  null       null
# 950907717 4908                                null  null       null
# 950907719 4908                                null  null       null
# 950907721 4908                                null  null       null
# 950907727 4908                                null  null       null
#
#                                 y_position color_triplet
# unit_id   stimulus_condition_id
# 950907256 4908                        null          null
# 950907717 4908                        null          null
# 950907719 4908                        null          null
# 950907721 4908                        null          null
# 950907727 4908                        null          null

# %%
from scipy.stats import sem
dg_male_scenes=statsm['spike_mean']/0.2502
standard_error_male_scenes=sem(dg_male_scenes)
dg_male_mean=dg_male_scenes.mean()

print(standard_error_male_scenes)
print('male Dentate Gyrus spike mean average in response to natural scenes:')
print(dg_male_mean)
# Out:
# 0.12249461051326328
# male Dentate Gyrus spike mean average in response to natural scenes:
# 9.10378071799584

# %%
statsmca1 = sessionm_ca1.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA1_unitsm.index.values
)

# display the parameters associated with each condition
statsmca1 = pd.merge(statsmca1, sessionm_ca1.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Male CA1 spike data in response to natural scenes')
# Out:
# Male CA1 spike data in response to natural scenes

# %%
from scipy.stats import sem
ca1_male_scenes=statsmca1['spike_mean']/0.2502
standard_error_male_scenes_ca1=sem(ca1_male_scenes)
ca1_male_mean=ca1_male_scenes.mean()

print(standard_error_male_scenes_ca1)
print('male ca1 spike mean average in response to natural scenes:')
print(ca1_male_mean)
# Out:
# 0.0895512739961898
# male ca1 spike mean average in response to natural scenes:
# 10.9864528781758

# %%
statsmca3 = sessionm_ca3.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA3_unitsm.index.values
)

# display the parameters associated with each condition
statsmca3 = pd.merge(statsmca3, sessionm_ca3.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Male CA3 spike data in response to natural scenes')
# Out:
# Male CA3 spike data in response to natural scenes

# %%
ca3_male_scenes=statsmca3['spike_mean']/0.2502
standard_error_male_scenes_ca3=sem(ca3_male_scenes)
print('ca3 male standard error')
print(standard_error_male_scenes_ca3)
ca3_male_mean=ca3_male_scenes.mean()
print('ca3 male mean')
print(ca3_male_mean)
#print(standard_error_male_scenes_ca3)
#print('male ca3 spike mean average in response to natural scenes:')
#print(ca3_male_scenes)
#print(ca3_male_mean)

newca3_male_movies=statsmca3_3['spike_count']/(20*0.033361)
#print(newca3_male_movies)
avg_male_movies=newca3_male_movies.mean()
#print(avg_male_movies)
# Out:
# ca3 male standard error
# 0.17170557150029736
# ca3 male mean
# 8.217694751761615

# %%
natural_scenes_presentation_ids = sessionf.stimulus_presentations.loc[
    (sessionf.stimulus_presentations['stimulus_name'] == 'natural_scenes')
].index.values

statsf = sessionf.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=DG_unitsf.index.values
)

# display the parameters associated with each condition
statsf = pd.merge(statsf, sessionf.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female Dentate Gyrus spike data in response to natural scenes')
print(statsf.shape[0])
statsf.head()
# Out:
# Female Dentate Gyrus spike data in response to natural scenes
# 3689
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951090214 4908                           168                           50
# 951095747 4908                            35                           50
# 951095759 4908                             1                           50
# 951095829 4908                            10                           50
# 951095847 4908                             2                           50
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951090214 4908                         3.36   2.640037   0.373358  null
# 951095747 4908                         0.70   1.865366   0.263803  null
# 951095759 4908                         0.02   0.141421   0.020000  null
# 951095829 4908                         0.20   0.494872   0.069985  null
# 951095847 4908                         0.04   0.197949   0.027994  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951090214 4908                      null  13.0  null    null        null
# 951095747 4908                      null  13.0  null    null        null
# 951095759 4908                      null  13.0  null    null        null
# 951095829 4908                      null  13.0  null    null        null
# 951095847 4908                      null  13.0  null    null        null
#
#                                 phase  size spatial_frequency   stimulus_name  \
# unit_id   stimulus_condition_id
# 951090214 4908                   null  null              null  natural_scenes
# 951095747 4908                   null  null              null  natural_scenes
# 951095759 4908                   null  null              null  natural_scenes
# 951095829 4908                   null  null              null  natural_scenes
# 951095847 4908                   null  null              null  natural_scenes
#
#                                 temporal_frequency units x_position  \
# unit_id   stimulus_condition_id
# 951090214 4908                                null  null       null
# 951095747 4908                                null  null       null
# 951095759 4908                                null  null       null
# 951095829 4908                                null  null       null
# 951095847 4908                                null  null       null
#
#                                 y_position color_triplet
# unit_id   stimulus_condition_id
# 951090214 4908                        null          null
# 951095747 4908                        null          null
# 951095759 4908                        null          null
# 951095829 4908                        null          null
# 951095847 4908                        null          null

# %%
fdgscenesfiringrate=statsf.spike_mean/0.2502
statsfnew=statsf.assign(sex='female', firing_rate=fdgscenesfiringrate, stimulus='scenes')
mdgscenesfiringrate=statsm.spike_mean/0.2502
statsmnew=statsm.assign(sex='male', firing_rate=mdgscenesfiringrate, stimulus='scenes')
mdgmoviesfiringrate=male_movie.spike_mean/0.033361
male_movienew=male_movie.assign(sex='male', firing_rate=mdgmoviesfiringrate, stimulus='movie')
fdgmoviesfiringrate=female_movie.spike_mean/0.033361
female_movienew=female_movie.assign(sex='female', firing_rate=fdgmoviesfiringrate, stimulus='movie')
frames=[statsfnew, statsmnew, male_movienew, female_movienew]
DGANOVA=pd.concat(frames)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model=ols('firing_rate ~ C(sex) + C(stimulus) + C(sex):C(stimulus)',data=DGANOVA).fit()
sm.stats.anova_lm(model,typ=2)
# Out:
#                           sum_sq        df            F    PR(>F)
# C(sex)              7.853500e+05       1.0  8363.832197  0.000000
# C(stimulus)         6.366864e+02       1.0     6.780593  0.009216
# C(sex):C(stimulus)  1.337557e+03       1.0    14.244740  0.000161
# Residual            3.122721e+07  332564.0          NaN       NaN

# %%
natural_scenes_presentation_ids = sessionf_ca1.stimulus_presentations.loc[
    (sessionf_ca1.stimulus_presentations['stimulus_name'] == 'natural_scenes')
].index.values

statsfca1 = sessionf_ca1.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA1_unitsf.index.values
)

# display the parameters associated with each condition
statsfca1 = pd.merge(statsfca1, sessionf_ca1.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female CA1 spike data in response to natural scenes')
print(statsfca1.shape[0])
statsfca1.head()
# Out:
# Female CA1 spike data in response to natural scenes
# 8568
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951779435 4908                            70                           50
# 951779456 4908                           116                           50
# 951779469 4908                            68                           50
# 951779510 4908                            78                           50
# 951779537 4908                           135                           50
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951779435 4908                         1.40   1.370238   0.193781  null
# 951779456 4908                         2.32   1.743091   0.246510  null
# 951779469 4908                         1.36   1.241461   0.175569  null
# 951779510 4908                         1.56   1.459102   0.206348  null
# 951779537 4908                         2.70   2.340853   0.331047  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951779435 4908                      null  29.0  null    null        null
# 951779456 4908                      null  29.0  null    null        null
# 951779469 4908                      null  29.0  null    null        null
# 951779510 4908                      null  29.0  null    null        null
# 951779537 4908                      null  29.0  null    null        null
#
#                                 phase  size spatial_frequency   stimulus_name  \
# unit_id   stimulus_condition_id
# 951779435 4908                   null  null              null  natural_scenes
# 951779456 4908                   null  null              null  natural_scenes
# 951779469 4908                   null  null              null  natural_scenes
# 951779510 4908                   null  null              null  natural_scenes
# 951779537 4908                   null  null              null  natural_scenes
#
#                                 temporal_frequency units x_position  \
# unit_id   stimulus_condition_id
# 951779435 4908                                null  null       null
# 951779456 4908                                null  null       null
# 951779469 4908                                null  null       null
# 951779510 4908                                null  null       null
# 951779537 4908                                null  null       null
#
#                                 y_position color_triplet
# unit_id   stimulus_condition_id
# 951779435 4908                        null          null
# 951779456 4908                        null          null
# 951779469 4908                        null          null
# 951779510 4908                        null          null
# 951779537 4908                        null          null

# %%
ca3_female_scenes=statsfca3['spike_mean']/0.2502
standard_error_female_scenes_ca3=sem(ca3_female_scenes)
ca3_female_mean=ca3_female_scenes.mean()

print(standard_error_female_scenes_ca3)
print('female ca3 spike mean average in response to natural scenes:')
print(ca3_female_mean)
# Out:
# 0.26032638713497636
# female ca3 spike mean average in response to natural scenes:
# 11.12069448082995

# %%
dg_female_scenes=statsf['spike_mean']/0.2502
standard_error_female_scenes=sem(dg_female_scenes)
dg_female_mean=dg_female_scenes.mean()

print(standard_error_female_scenes)
print('female dentate gyrus spike mean average in response to natural scenes:')
print(dg_female_mean)
# Out:
# 0.14063330371304916
# female dentate gyrus spike mean average in response to natural scenes:
# 6.787890370815352

# %%
ca1_female_scenes=statsfca1['spike_mean']/0.2502
standard_error_female_scenes_ca1=sem(ca1_female_scenes)
ca1_female_mean=ca1_female_scenes.mean()

print(standard_error_female_scenes_ca1)
print('female ca1 spike mean average in response to natural scenes:')
print(ca1_female_mean)
# Out:
# 0.06560210190318003
# female ca1 spike mean average in response to natural scenes:
# 6.522942243777485

# %%
dg_male_scenes=statsm['spike_mean']/0.2502
standard_error_male_scenes=sem(dg_male_scenes)
dg_male_mean=dg_male_scenes.mean()

print(standard_error_male_scenes)
print('male dentate gyrus spike mean average in response to natural scenes:')
print(dg_male_mean)
# Out:
# 0.12249461051326328
# male dentate gyrus spike mean average in response to natural scenes:
# 9.10378071799584

# %%
natural_scenes_presentation_ids = sessionf_ca3.stimulus_presentations.loc[
    (sessionf_ca3.stimulus_presentations['stimulus_name'] == 'natural_scenes')
].index.values

statsfca3 = sessionf_ca3.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA3_unitsf.index.values
)

# display the parameters associated with each condition
statsfca3 = pd.merge(statsfca3, sessionf_ca3.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female CA3 spike data in response to natural scenes')
statsfca3.head()
# Out:
# Female CA3 spike data in response to natural scenes
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951779253 4908                            14                           50
# 951779304 4908                            49                           50
# 951779308 4908                           592                           50
# 951779349 4908                           109                           50
# 951779358 4908                            99                           50
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951779253 4908                         0.28   0.729551   0.103174  null
# 951779304 4908                         0.98   1.647385   0.232975  null
# 951779308 4908                        11.84   4.042428   0.571686  null
# 951779349 4908                         2.18   1.902630   0.269072  null
# 951779358 4908                         1.98   2.281156   0.322604  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951779253 4908                      null  29.0  null    null        null
# 951779304 4908                      null  29.0  null    null        null
# 951779308 4908                      null  29.0  null    null        null
# 951779349 4908                      null  29.0  null    null        null
# 951779358 4908                      null  29.0  null    null        null
#
#                                 phase  size spatial_frequency   stimulus_name  \
# unit_id   stimulus_condition_id
# 951779253 4908                   null  null              null  natural_scenes
# 951779304 4908                   null  null              null  natural_scenes
# 951779308 4908                   null  null              null  natural_scenes
# 951779349 4908                   null  null              null  natural_scenes
# 951779358 4908                   null  null              null  natural_scenes
#
#                                 temporal_frequency units x_position  \
# unit_id   stimulus_condition_id
# 951779253 4908                                null  null       null
# 951779304 4908                                null  null       null
# 951779308 4908                                null  null       null
# 951779349 4908                                null  null       null
# 951779358 4908                                null  null       null
#
#                                 y_position color_triplet
# unit_id   stimulus_condition_id
# 951779253 4908                        null          null
# 951779304 4908                        null          null
# 951779308 4908                        null          null
# 951779349 4908                        null          null
# 951779358 4908                        null          null

# %%
natural_scenes_presentation_ids = sessionm.stimulus_presentations.loc[
    (sessionm.stimulus_presentations['stimulus_name'] == 'natural_movie_one')
].index.values

statsm1 = sessionm.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=DG_unitsm.index.values
)

# display the parameters associated with each condition
statsm1 = pd.merge(statsm1, sessionm.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)


print ('Male Dentate Gyrus spike data in response to natural movie one')
statsm1.head()
# Out:
# Male Dentate Gyrus spike data in response to natural movie one
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 950907256 3887                             0                           20
# 950907717 3887                             6                           20
# 950907719 3887                            16                           20
# 950907721 3887                            11                           20
# 950907727 3887                             9                           20
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 950907256 3887                         0.00   0.000000   0.000000  null
# 950907717 3887                         0.30   0.923381   0.206474  null
# 950907719 3887                         0.80   1.196486   0.267542  null
# 950907721 3887                         0.55   0.887041   0.198348  null
# 950907727 3887                         0.45   0.998683   0.223312  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 950907256 3887                       1.0   0.0  null     1.0         0.0
# 950907717 3887                       1.0   0.0  null     1.0         0.0
# 950907719 3887                       1.0   0.0  null     1.0         0.0
# 950907721 3887                       1.0   0.0  null     1.0         0.0
# 950907727 3887                       1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 950907256 3887                   null  [1920.0, 1080.0]              null
# 950907717 3887                   null  [1920.0, 1080.0]              null
# 950907719 3887                   null  [1920.0, 1080.0]              null
# 950907721 3887                   null  [1920.0, 1080.0]              null
# 950907727 3887                   null  [1920.0, 1080.0]              null
#
#                                      stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 950907256 3887                   natural_movie_one               null   pix
# 950907717 3887                   natural_movie_one               null   pix
# 950907719 3887                   natural_movie_one               null   pix
# 950907721 3887                   natural_movie_one               null   pix
# 950907727 3887                   natural_movie_one               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 950907256 3887                        null       null  [1.0, 1.0, 1.0]
# 950907717 3887                        null       null  [1.0, 1.0, 1.0]
# 950907719 3887                        null       null  [1.0, 1.0, 1.0]
# 950907721 3887                        null       null  [1.0, 1.0, 1.0]
# 950907727 3887                        null       null  [1.0, 1.0, 1.0]

# %%
natural_scenes_presentation_ids = sessionm_ca1.stimulus_presentations.loc[
    (sessionm_ca1.stimulus_presentations['stimulus_name'] == 'natural_movie_one')
].index.values

statsmca1_1 = sessionm_ca1.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA1_unitsm.index.values
)

# display the parameters associated with each condition
statsmca1_1 = pd.merge(statsmca1_1, sessionm_ca1.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)


print ('Male CA1 spike data in response to natural movie one')
statsmca1_1.head()
# Out:
# Male CA1 spike data in response to natural movie one
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 950907296 3887                             2                           20
# 950907301 3887                            11                           20
# 950907306 3887                             6                           20
# 950907314 3887                             4                           20
# 950907319 3887                            13                           20
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 950907296 3887                         0.10   0.307794   0.068825  null
# 950907301 3887                         0.55   0.887041   0.198348  null
# 950907306 3887                         0.30   0.656947   0.146898  null
# 950907314 3887                         0.20   0.695852   0.155597  null
# 950907319 3887                         0.65   0.670820   0.150000  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 950907296 3887                       1.0   0.0  null     1.0         0.0
# 950907301 3887                       1.0   0.0  null     1.0         0.0
# 950907306 3887                       1.0   0.0  null     1.0         0.0
# 950907314 3887                       1.0   0.0  null     1.0         0.0
# 950907319 3887                       1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 950907296 3887                   null  [1920.0, 1080.0]              null
# 950907301 3887                   null  [1920.0, 1080.0]              null
# 950907306 3887                   null  [1920.0, 1080.0]              null
# 950907314 3887                   null  [1920.0, 1080.0]              null
# 950907319 3887                   null  [1920.0, 1080.0]              null
#
#                                      stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 950907296 3887                   natural_movie_one               null   pix
# 950907301 3887                   natural_movie_one               null   pix
# 950907306 3887                   natural_movie_one               null   pix
# 950907314 3887                   natural_movie_one               null   pix
# 950907319 3887                   natural_movie_one               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 950907296 3887                        null       null  [1.0, 1.0, 1.0]
# 950907301 3887                        null       null  [1.0, 1.0, 1.0]
# 950907306 3887                        null       null  [1.0, 1.0, 1.0]
# 950907314 3887                        null       null  [1.0, 1.0, 1.0]
# 950907319 3887                        null       null  [1.0, 1.0, 1.0]

# %%
natural_scenes_presentation_ids = sessionm_ca3.stimulus_presentations.loc[
    (sessionm_ca3.stimulus_presentations['stimulus_name'] == 'natural_movie_one')
].index.values

statsmca3_1 = sessionm_ca3.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA3_unitsm.index.values
)

# display the parameters associated with each condition
statsmca3_1 = pd.merge(statsmca3_1, sessionm_ca3.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)


print ('Male CA3 spike data in response to natural movie one')
statsmca3_1.head()
# Out:
# Male CA3 spike data in response to natural movie one
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 950909160 3887                             4                           20
# 950909164 3887                            11                           20
# 950909583 3887                             8                           20
# 950909993 3887                             4                           20
# 950909997 3887                            18                           20
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 950909160 3887                         0.20   0.410391   0.091766  null
# 950909164 3887                         0.55   0.686333   0.153469  null
# 950909583 3887                         0.40   0.598243   0.133771  null
# 950909993 3887                         0.20   0.410391   0.091766  null
# 950909997 3887                         0.90   1.119210   0.250263  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 950909160 3887                       1.0   0.0  null     1.0         0.0
# 950909164 3887                       1.0   0.0  null     1.0         0.0
# 950909583 3887                       1.0   0.0  null     1.0         0.0
# 950909993 3887                       1.0   0.0  null     1.0         0.0
# 950909997 3887                       1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 950909160 3887                   null  [1920.0, 1080.0]              null
# 950909164 3887                   null  [1920.0, 1080.0]              null
# 950909583 3887                   null  [1920.0, 1080.0]              null
# 950909993 3887                   null  [1920.0, 1080.0]              null
# 950909997 3887                   null  [1920.0, 1080.0]              null
#
#                                      stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 950909160 3887                   natural_movie_one               null   pix
# 950909164 3887                   natural_movie_one               null   pix
# 950909583 3887                   natural_movie_one               null   pix
# 950909993 3887                   natural_movie_one               null   pix
# 950909997 3887                   natural_movie_one               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 950909160 3887                        null       null  [1.0, 1.0, 1.0]
# 950909164 3887                        null       null  [1.0, 1.0, 1.0]
# 950909583 3887                        null       null  [1.0, 1.0, 1.0]
# 950909993 3887                        null       null  [1.0, 1.0, 1.0]
# 950909997 3887                        null       null  [1.0, 1.0, 1.0]

# %%
natural_scenes_presentation_ids = sessionf.stimulus_presentations.loc[
    (sessionf.stimulus_presentations['stimulus_name'] == 'natural_movie_one')
].index.values

statsf1 = sessionf.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=DG_unitsf.index.values
)

# display the parameters associated with each condition
statsf1 = pd.merge(statsf1, sessionf.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female DG spike data in response to natural movie one')
statsf1.head()
# Out:
# Female DG spike data in response to natural movie one
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951090214 3887                             2                           20
# 951095747 3887                             0                           20
# 951095759 3887                             0                           20
# 951095829 3887                             0                           20
# 951095847 3887                             0                           20
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951090214 3887                          0.1   0.447214        0.1  null
# 951095747 3887                          0.0   0.000000        0.0  null
# 951095759 3887                          0.0   0.000000        0.0  null
# 951095829 3887                          0.0   0.000000        0.0  null
# 951095847 3887                          0.0   0.000000        0.0  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951090214 3887                       1.0   0.0  null     1.0         0.0
# 951095747 3887                       1.0   0.0  null     1.0         0.0
# 951095759 3887                       1.0   0.0  null     1.0         0.0
# 951095829 3887                       1.0   0.0  null     1.0         0.0
# 951095847 3887                       1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 951090214 3887                   null  [1920.0, 1080.0]              null
# 951095747 3887                   null  [1920.0, 1080.0]              null
# 951095759 3887                   null  [1920.0, 1080.0]              null
# 951095829 3887                   null  [1920.0, 1080.0]              null
# 951095847 3887                   null  [1920.0, 1080.0]              null
#
#                                      stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 951090214 3887                   natural_movie_one               null   pix
# 951095747 3887                   natural_movie_one               null   pix
# 951095759 3887                   natural_movie_one               null   pix
# 951095829 3887                   natural_movie_one               null   pix
# 951095847 3887                   natural_movie_one               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 951090214 3887                        null       null  [1.0, 1.0, 1.0]
# 951095747 3887                        null       null  [1.0, 1.0, 1.0]
# 951095759 3887                        null       null  [1.0, 1.0, 1.0]
# 951095829 3887                        null       null  [1.0, 1.0, 1.0]
# 951095847 3887                        null       null  [1.0, 1.0, 1.0]

# %%
natural_scenes_presentation_ids = sessionf_ca1.stimulus_presentations.loc[
    (sessionf_ca1.stimulus_presentations['stimulus_name'] == 'natural_movie_one')
].index.values

statsfca1_1 = sessionf_ca1.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA1_unitsf.index.values
)

# display the parameters associated with each condition
statsfca1_1 = pd.merge(statsfca1_1, sessionf_ca1.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

#print ('Female CA1 spike data in response to natural movie one')
#statsfca1_1.head()

# %%
natural_scenes_presentation_ids = sessionf_ca3.stimulus_presentations.loc[
    (sessionf_ca3.stimulus_presentations['stimulus_name'] == 'natural_movie_one')
].index.values

statsfca3_1 = sessionf_ca3.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_scenes_presentation_ids,
    unit_ids=CA3_unitsf.index.values
)

# display the parameters associated with each condition
statsfca3_1 = pd.merge(statsfca3_1, sessionf_ca3.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female CA3 spike data in response to natural movie one')
statsfca3_1.head()
# Out:
# Female CA3 spike data in response to natural movie one
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951779253 3887                             1                           20
# 951779304 3887                             2                           20
# 951779308 3887                            25                           20
# 951779349 3887                             7                           20
# 951779358 3887                             8                           20
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951779253 3887                         0.05   0.223607   0.050000  null
# 951779304 3887                         0.10   0.307794   0.068825  null
# 951779308 3887                         1.25   1.332785   0.298020  null
# 951779349 3887                         0.35   0.670820   0.150000  null
# 951779358 3887                         0.40   0.598243   0.133771  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951779253 3887                       1.0   0.0  null     1.0         0.0
# 951779304 3887                       1.0   0.0  null     1.0         0.0
# 951779308 3887                       1.0   0.0  null     1.0         0.0
# 951779349 3887                       1.0   0.0  null     1.0         0.0
# 951779358 3887                       1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 951779253 3887                   null  [1920.0, 1080.0]              null
# 951779304 3887                   null  [1920.0, 1080.0]              null
# 951779308 3887                   null  [1920.0, 1080.0]              null
# 951779349 3887                   null  [1920.0, 1080.0]              null
# 951779358 3887                   null  [1920.0, 1080.0]              null
#
#                                      stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 951779253 3887                   natural_movie_one               null   pix
# 951779304 3887                   natural_movie_one               null   pix
# 951779308 3887                   natural_movie_one               null   pix
# 951779349 3887                   natural_movie_one               null   pix
# 951779358 3887                   natural_movie_one               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 951779253 3887                        null       null  [1.0, 1.0, 1.0]
# 951779304 3887                        null       null  [1.0, 1.0, 1.0]
# 951779308 3887                        null       null  [1.0, 1.0, 1.0]
# 951779349 3887                        null       null  [1.0, 1.0, 1.0]
# 951779358 3887                        null       null  [1.0, 1.0, 1.0]

# %%
natural_movies_presentation_ids = sessionm.stimulus_presentations.loc[
    (sessionm.stimulus_presentations['stimulus_name'] == 'natural_movie_three')
].index.values

statsm3 = sessionm.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_movies_presentation_ids,
    unit_ids=DG_unitsm.index.values
)

# display the parameters associated with each condition
statsm3 = pd.merge(statsm3, sessionm.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Male DG spike data in response to natural movie three')
statsm3.head()
# Out:
# Male DG spike data in response to natural movie three
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 950907256 287                              0                           10
# 950907717 287                              0                           10
# 950907719 287                              2                           10
# 950907721 287                              2                           10
# 950907727 287                              1                           10
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 950907256 287                           0.0   0.000000        0.0  null
# 950907717 287                           0.0   0.000000        0.0  null
# 950907719 287                           0.2   0.632456        0.2  null
# 950907721 287                           0.2   0.632456        0.2  null
# 950907727 287                           0.1   0.316228        0.1  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 950907256 287                        1.0   0.0  null     1.0         0.0
# 950907717 287                        1.0   0.0  null     1.0         0.0
# 950907719 287                        1.0   0.0  null     1.0         0.0
# 950907721 287                        1.0   0.0  null     1.0         0.0
# 950907727 287                        1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 950907256 287                    null  [1920.0, 1080.0]              null
# 950907717 287                    null  [1920.0, 1080.0]              null
# 950907719 287                    null  [1920.0, 1080.0]              null
# 950907721 287                    null  [1920.0, 1080.0]              null
# 950907727 287                    null  [1920.0, 1080.0]              null
#
#                                        stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 950907256 287                    natural_movie_three               null   pix
# 950907717 287                    natural_movie_three               null   pix
# 950907719 287                    natural_movie_three               null   pix
# 950907721 287                    natural_movie_three               null   pix
# 950907727 287                    natural_movie_three               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 950907256 287                         null       null  [1.0, 1.0, 1.0]
# 950907717 287                         null       null  [1.0, 1.0, 1.0]
# 950907719 287                         null       null  [1.0, 1.0, 1.0]
# 950907721 287                         null       null  [1.0, 1.0, 1.0]
# 950907727 287                         null       null  [1.0, 1.0, 1.0]

# %%
natural_movies_presentation_ids = sessionm_ca1.stimulus_presentations.loc[
    (sessionm_ca1.stimulus_presentations['stimulus_name'] == 'natural_movie_three')
].index.values

statsmca1_3 = sessionm_ca1.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_movies_presentation_ids,
    unit_ids=CA1_unitsm.index.values
)

# display the parameters associated with each condition
statsmca1_3 = pd.merge(statsmca1_3, sessionm_ca1.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Male CA1 spike data in response to natural movie three')
statsmca1_3.head()
# Out:
# Male CA1 spike data in response to natural movie three
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 950907296 287                              3                           10
# 950907301 287                              3                           10
# 950907306 287                              2                           10
# 950907314 287                              2                           10
# 950907319 287                              6                           10
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 950907296 287                           0.3   0.948683   0.300000  null
# 950907301 287                           0.3   0.483046   0.152753  null
# 950907306 287                           0.2   0.421637   0.133333  null
# 950907314 287                           0.2   0.421637   0.133333  null
# 950907319 287                           0.6   0.516398   0.163299  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 950907296 287                        1.0   0.0  null     1.0         0.0
# 950907301 287                        1.0   0.0  null     1.0         0.0
# 950907306 287                        1.0   0.0  null     1.0         0.0
# 950907314 287                        1.0   0.0  null     1.0         0.0
# 950907319 287                        1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 950907296 287                    null  [1920.0, 1080.0]              null
# 950907301 287                    null  [1920.0, 1080.0]              null
# 950907306 287                    null  [1920.0, 1080.0]              null
# 950907314 287                    null  [1920.0, 1080.0]              null
# 950907319 287                    null  [1920.0, 1080.0]              null
#
#                                        stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 950907296 287                    natural_movie_three               null   pix
# 950907301 287                    natural_movie_three               null   pix
# 950907306 287                    natural_movie_three               null   pix
# 950907314 287                    natural_movie_three               null   pix
# 950907319 287                    natural_movie_three               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 950907296 287                         null       null  [1.0, 1.0, 1.0]
# 950907301 287                         null       null  [1.0, 1.0, 1.0]
# 950907306 287                         null       null  [1.0, 1.0, 1.0]
# 950907314 287                         null       null  [1.0, 1.0, 1.0]
# 950907319 287                         null       null  [1.0, 1.0, 1.0]

# %%
natural_movies_presentation_ids = sessionm_ca3.stimulus_presentations.loc[
    (sessionm_ca3.stimulus_presentations['stimulus_name'] == 'natural_movie_three')
].index.values

statsmca3_3 = sessionm_ca3.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_movies_presentation_ids,
    unit_ids=CA3_unitsm.index.values
)

# display the parameters associated with each condition
statsmca3_3 = pd.merge(statsmca3_3, sessionm_ca3.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Male CA3 spike data in response to natural movie three')
statsmca3_3.head()
# Out:
# Male CA3 spike data in response to natural movie three
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 950909160 287                              5                           10
# 950909164 287                              2                           10
# 950909583 287                              0                           10
# 950909993 287                              0                           10
# 950909997 287                              3                           10
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 950909160 287                           0.5   0.707107   0.223607  null
# 950909164 287                           0.2   0.421637   0.133333  null
# 950909583 287                           0.0   0.000000   0.000000  null
# 950909993 287                           0.0   0.000000   0.000000  null
# 950909997 287                           0.3   0.674949   0.213437  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 950909160 287                        1.0   0.0  null     1.0         0.0
# 950909164 287                        1.0   0.0  null     1.0         0.0
# 950909583 287                        1.0   0.0  null     1.0         0.0
# 950909993 287                        1.0   0.0  null     1.0         0.0
# 950909997 287                        1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 950909160 287                    null  [1920.0, 1080.0]              null
# 950909164 287                    null  [1920.0, 1080.0]              null
# 950909583 287                    null  [1920.0, 1080.0]              null
# 950909993 287                    null  [1920.0, 1080.0]              null
# 950909997 287                    null  [1920.0, 1080.0]              null
#
#                                        stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 950909160 287                    natural_movie_three               null   pix
# 950909164 287                    natural_movie_three               null   pix
# 950909583 287                    natural_movie_three               null   pix
# 950909993 287                    natural_movie_three               null   pix
# 950909997 287                    natural_movie_three               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 950909160 287                         null       null  [1.0, 1.0, 1.0]
# 950909164 287                         null       null  [1.0, 1.0, 1.0]
# 950909583 287                         null       null  [1.0, 1.0, 1.0]
# 950909993 287                         null       null  [1.0, 1.0, 1.0]
# 950909997 287                         null       null  [1.0, 1.0, 1.0]

# %%
natural_movies_presentation_ids = sessionf.stimulus_presentations.loc[
    (sessionf.stimulus_presentations['stimulus_name'] == 'natural_movie_three')
].index.values

statsf3 = sessionf.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_movies_presentation_ids,
    unit_ids=DG_unitsf.index.values
)

# display the parameters associated with each condition
statsf3 = pd.merge(statsf3, sessionf.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female DG spike data in response to natural movie three')
statsf3.head()
# Out:
# Female DG spike data in response to natural movie three
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951090214 287                              1                           10
# 951095747 287                              2                           10
# 951095759 287                              0                           10
# 951095829 287                              0                           10
# 951095847 287                              0                           10
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951090214 287                           0.1   0.316228        0.1  null
# 951095747 287                           0.2   0.632456        0.2  null
# 951095759 287                           0.0   0.000000        0.0  null
# 951095829 287                           0.0   0.000000        0.0  null
# 951095847 287                           0.0   0.000000        0.0  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951090214 287                        1.0   0.0  null     1.0         0.0
# 951095747 287                        1.0   0.0  null     1.0         0.0
# 951095759 287                        1.0   0.0  null     1.0         0.0
# 951095829 287                        1.0   0.0  null     1.0         0.0
# 951095847 287                        1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 951090214 287                    null  [1920.0, 1080.0]              null
# 951095747 287                    null  [1920.0, 1080.0]              null
# 951095759 287                    null  [1920.0, 1080.0]              null
# 951095829 287                    null  [1920.0, 1080.0]              null
# 951095847 287                    null  [1920.0, 1080.0]              null
#
#                                        stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 951090214 287                    natural_movie_three               null   pix
# 951095747 287                    natural_movie_three               null   pix
# 951095759 287                    natural_movie_three               null   pix
# 951095829 287                    natural_movie_three               null   pix
# 951095847 287                    natural_movie_three               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 951090214 287                         null       null  [1.0, 1.0, 1.0]
# 951095747 287                         null       null  [1.0, 1.0, 1.0]
# 951095759 287                         null       null  [1.0, 1.0, 1.0]
# 951095829 287                         null       null  [1.0, 1.0, 1.0]
# 951095847 287                         null       null  [1.0, 1.0, 1.0]

# %%
natural_movies_presentation_ids = sessionf_ca1.stimulus_presentations.loc[
    (sessionf_ca1.stimulus_presentations['stimulus_name'] == 'natural_movie_three')
].index.values

statsfca1_3 = sessionf_ca1.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_movies_presentation_ids,
    unit_ids=CA1_unitsf.index.values
)

# display the parameters associated with each condition
statsfca1_3 = pd.merge(statsfca1_3, sessionf_ca1.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female CA1 spike data in response to natural movie three')
statsfca1_3.head()
# Out:
# Female CA1 spike data in response to natural movie three
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951779435 287                              2                           10
# 951779456 287                              1                           10
# 951779469 287                              2                           10
# 951779510 287                              1                           10
# 951779537 287                              3                           10
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951779435 287                           0.2   0.421637   0.133333  null
# 951779456 287                           0.1   0.316228   0.100000  null
# 951779469 287                           0.2   0.421637   0.133333  null
# 951779510 287                           0.1   0.316228   0.100000  null
# 951779537 287                           0.3   0.674949   0.213437  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951779435 287                        1.0   0.0  null     1.0         0.0
# 951779456 287                        1.0   0.0  null     1.0         0.0
# 951779469 287                        1.0   0.0  null     1.0         0.0
# 951779510 287                        1.0   0.0  null     1.0         0.0
# 951779537 287                        1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 951779435 287                    null  [1920.0, 1080.0]              null
# 951779456 287                    null  [1920.0, 1080.0]              null
# 951779469 287                    null  [1920.0, 1080.0]              null
# 951779510 287                    null  [1920.0, 1080.0]              null
# 951779537 287                    null  [1920.0, 1080.0]              null
#
#                                        stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 951779435 287                    natural_movie_three               null   pix
# 951779456 287                    natural_movie_three               null   pix
# 951779469 287                    natural_movie_three               null   pix
# 951779510 287                    natural_movie_three               null   pix
# 951779537 287                    natural_movie_three               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 951779435 287                         null       null  [1.0, 1.0, 1.0]
# 951779456 287                         null       null  [1.0, 1.0, 1.0]
# 951779469 287                         null       null  [1.0, 1.0, 1.0]
# 951779510 287                         null       null  [1.0, 1.0, 1.0]
# 951779537 287                         null       null  [1.0, 1.0, 1.0]

# %%
natural_movies_presentation_ids = sessionf_ca3.stimulus_presentations.loc[
    (sessionf_ca3.stimulus_presentations['stimulus_name'] == 'natural_movie_three')
].index.values

statsfca3_3 = sessionf_ca3.conditionwise_spike_statistics(
    stimulus_presentation_ids=natural_movies_presentation_ids,
    unit_ids=CA3_unitsf.index.values
)

# display the parameters associated with each condition
statsfca3_3 = pd.merge(statsfca3_3, sessionf_ca3.stimulus_conditions, left_on="stimulus_condition_id", right_index=True)

print ('Female CA3 spike data in response to natural movie three')
statsfca3_3.head()
# Out:
# Female CA3 spike data in response to natural movie three
#                                  spike_count  stimulus_presentation_count  \
# unit_id   stimulus_condition_id
# 951779253 287                              4                           10
# 951779304 287                              1                           10
# 951779308 287                             14                           10
# 951779349 287                              2                           10
# 951779358 287                              3                           10
#
#                                  spike_mean  spike_std  spike_sem color  \
# unit_id   stimulus_condition_id
# 951779253 287                           0.4   0.699206   0.221108  null
# 951779304 287                           0.1   0.316228   0.100000  null
# 951779308 287                           1.4   1.173788   0.371184  null
# 951779349 287                           0.2   0.421637   0.133333  null
# 951779358 287                           0.3   0.674949   0.213437  null
#
#                                 contrast frame  mask opacity orientation  \
# unit_id   stimulus_condition_id
# 951779253 287                        1.0   0.0  null     1.0         0.0
# 951779304 287                        1.0   0.0  null     1.0         0.0
# 951779308 287                        1.0   0.0  null     1.0         0.0
# 951779349 287                        1.0   0.0  null     1.0         0.0
# 951779358 287                        1.0   0.0  null     1.0         0.0
#
#                                 phase              size spatial_frequency  \
# unit_id   stimulus_condition_id
# 951779253 287                    null  [1920.0, 1080.0]              null
# 951779304 287                    null  [1920.0, 1080.0]              null
# 951779308 287                    null  [1920.0, 1080.0]              null
# 951779349 287                    null  [1920.0, 1080.0]              null
# 951779358 287                    null  [1920.0, 1080.0]              null
#
#                                        stimulus_name temporal_frequency units  \
# unit_id   stimulus_condition_id
# 951779253 287                    natural_movie_three               null   pix
# 951779304 287                    natural_movie_three               null   pix
# 951779308 287                    natural_movie_three               null   pix
# 951779349 287                    natural_movie_three               null   pix
# 951779358 287                    natural_movie_three               null   pix
#
#                                 x_position y_position    color_triplet
# unit_id   stimulus_condition_id
# 951779253 287                         null       null  [1.0, 1.0, 1.0]
# 951779304 287                         null       null  [1.0, 1.0, 1.0]
# 951779308 287                         null       null  [1.0, 1.0, 1.0]
# 951779349 287                         null       null  [1.0, 1.0, 1.0]
# 951779358 287                         null       null  [1.0, 1.0, 1.0]

# %%
male_movie=pd.concat([statsm1,statsm3])
female_movie=pd.concat([statsf1,statsf3])
dg_female_movies=female_movie['spike_mean']/0.033361
dg_male_movies=male_movie['spike_mean']//0.033361
dg_female_mean_movies=dg_female_movies.mean()
dg_male_mean_movies=dg_male_movies.mean()
from scipy.stats import sem
standard_error_male_movies=sem(dg_male_movies)
print('dg standard error male movies')
print(standard_error_male_movies)
standard_error_female_movies=sem(dg_female_movies)
print('dg standard error female movies')
print(standard_error_female_movies)

print('female dentate gyrus spike mean average in response to natural movies:')
print(dg_female_mean_movies)
print('male dentate gyrus spike mean average in response to natural movies:')
print(dg_male_mean_movies)

male_movie_ca1=pd.concat([statsmca1_1,statsmca1_3])
female_movie_ca1=pd.concat([statsfca1_1,statsfca1_3])
ca1_female_movies=female_movie_ca1['spike_mean']/0.033361
ca1_male_movies=male_movie_ca1['spike_mean']/0.033361
ca1_female_mean_movies=ca1_female_movies.mean()
print('ca1 female mean movies')
print(ca1_female_mean_movies)
ca1_male_mean_movies=ca1_male_movies.mean()
print('ca1 male mean movies')
print(ca1_male_mean_movies)
standard_error_male_movies_ca1=sem(ca1_male_movies)
print('ca1 standard error male movies')
print(standard_error_male_movies_ca1)
standard_error_female_movies_ca1=sem(ca1_female_movies)
print('ca1 standard error female movies')
print(standard_error_female_movies_ca1)

male_movie_ca3=pd.concat([statsmca3_1,statsmca3_3])
female_movie_ca3=pd.concat([statsfca3_1,statsfca3_3])
ca3_female_movies=female_movie_ca3['spike_mean']/0.033361
ca3_male_movies=male_movie_ca3['spike_mean']/0.033361
ca3_female_mean_movies=ca3_female_movies.mean()
print('ca3 female mean movies')
print(ca3_female_mean_movies)
ca3_male_mean_movies=ca3_male_movies.mean()
print('ca3 male mean movies')
print(ca3_male_mean_movies)
standard_error_male_movies_ca3=sem(ca3_male_movies)
print('ca3 standard error male movies')
print(standard_error_male_movies_ca3)
standard_error_female_movies_ca3=sem(ca3_female_movies)
print('ca3 standard error female movies')
print(standard_error_female_movies_ca3)
# Out:
# dg standard error male movies
# 0.022672920368849048
# dg standard error female movies
# 0.025279190152833374
# female dentate gyrus spike mean average in response to natural movies:
# 6.051353720502503
# male dentate gyrus spike mean average in response to natural movies:
# 8.449739837398374
# ca1 female mean movies
# 7.322561163104746
# ca1 male mean movies
# 10.61950505960246
# ca1 standard error male movies
# 0.019421591544631817
# ca1 standard error female movies
# 0.01575588377103703
# ca3 female mean movies
# 11.873256308381897
# ca3 male mean movies
# 7.159757401359474
# ca3 standard error male movies
# 0.03191255646993691
# ca3 standard error female movies
# 0.04395033268623642

# %% [markdown]
# ## Add significance bars to graphs

# %%
import matplotlib.pyplot

# %%
value_listdg1 = [dg_female_mean, dg_female_mean_movies]
value_listdg2 = [dg_male_mean, dg_male_mean_movies]
name_listdg1=['female scenes','male scenes']
name_listdg2=['female movies','male movies']
x=np.arange(2)
width=0.40
plt.bar(x-0.2, value_listdg1, width)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Stimulus')
plt.title('Average DG Firing Rate')

plt.xticks(x, ['scenes', 'movies'])
plt.bar(x+0.2, value_listdg2, width)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Stimulus')
plt.title('Average DG Firing Rate')
standard_error_scenes_list=[standard_error_female_scenes, standard_error_male_scenes]
standard_error_movies_list=[standard_error_female_movies, standard_error_male_movies]
plt.errorbar(x-0.2, y=value_listdg1, yerr=standard_error_scenes_list, fmt='o', color='r', capsize=3)
plt.errorbar(x+0.2, y=value_listdg2, yerr=standard_error_movies_list, fmt='o', color='r', capsize=3)
plt.legend(['female', 'male'], bbox_to_anchor =(1.5, 1.0), ncol = 1)
'''from matplotlib.markers import TICKDOWN

def significance_bar(start,end,height,displaystring,linewidth = 1.2,markersize = 8,boxpad  =0.3,fontsize = 15,color = 'k'):
    # draw a line with downticks at the ends
    plt.plot([start,end],[height]*2,'-',color = color,lw=linewidth,marker = TICKDOWN,markeredgewidth=linewidth,markersize = markersize)
    # draw the text with a bounding box covering up the line
    plt.text(0.5*(start+end),height,displaystring=r'***',ha = 'center',va='center',bbox=dict(facecolor='1.', edgecolor='none',boxstyle='Square,pad='+str(boxpad)),size = fontsize)
offset=1
height = offset +  max(dg_female_mean,dg_male_mean)'''
# Out:
# "from matplotlib.markers import TICKDOWN\n\ndef significance_bar(start,end,height,displaystring,linewidth = 1.2,markersize = 8,boxpad  =0.3,fontsize = 15,color = 'k'):\n    # draw a line with downticks at the ends\n    plt.plot([start,end],[height]*2,'-',color = color,lw=linewidth,marker = TICKDOWN,markeredgewidth=linewidth,markersize = markersize)\n    # draw the text with a bounding box covering up the line\n    plt.text(0.5*(start+end),height,displaystring=r'***',ha = 'center',va='center',bbox=dict(facecolor='1.', edgecolor='none',boxstyle='Square,pad='+str(boxpad)),size = fontsize)\noffset=1\nheight = offset +  max(dg_female_mean,dg_male_mean)"

# %%
value_list = [dg_female_mean_movies, dg_male_mean_movies]
name_list=['female','male']
plt.bar(name_list, value_list)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Sex')
plt.title('Average DG Firing Rate in Response to Natural Movies')
standard_error_movies_list=[standard_error_male_movies, standard_error_female_movies]
plt.errorbar(x=name_list, y=value_list, yerr=standard_error_movies_list, fmt='o', color='r', capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#value_list = [ca1_female_mean, ca1_male_mean]
#name_list=['female','male']
#plt.bar(name_list, value_list)
#plt.ylabel('Average Firing Rate (Hz)')
#plt.xlabel('Sex')
#plt.title('Average CA1 Firing Rate in Response to Natural Scenes')
#standard_error_scenes_list_ca1=[standard_error_male_scenes_ca1, standard_error_female_scenes_ca1]
#plt.errorbar(x=name_list, y=value_list, yerr=standard_error_scenes_list_ca1, fmt='o', color='r', capsize=3)

value_listca1_1 = [ca1_female_mean, ca1_male_mean]
value_listca1_2 = [ca1_female_mean_movies, ca1_male_mean_movies]
name_listca1_1=['female scenes','male scenes']
name_listca1_2=['female movies','male movies']
x=np.arange(2)
width=0.40
plt.bar(x-0.2, value_listca1_1, width)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Stimulus')
plt.title('Average CA1 Firing Rate')

plt.xticks(x, ['scenes', 'movies'])
plt.bar(x+0.2, value_listca1_2, width)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Stimulus')
plt.title('Average CA1 Firing Rate')
standard_error_scenes_list_ca1=[standard_error_female_scenes_ca1, standard_error_male_scenes_ca1]
standard_error_movies_list_ca1=[standard_error_female_movies_ca1, standard_error_male_movies_ca1]
plt.errorbar(x-0.2, y=value_listca1_1, yerr=standard_error_scenes_list_ca1, fmt='o', color='r', capsize=3)
plt.errorbar(x+0.2, y=value_listca1_2, yerr=standard_error_movies_list_ca1, fmt='o', color='r', capsize=3)
#plt.legend(['female','male'], loc='upper right')
plt.legend(['female', 'male'], bbox_to_anchor =(1.5, 1.0), ncol = 1)

# %%
value_list = [ca1_female_mean_movies, ca1_male_mean_movies]
name_list=['female','male']
plt.bar(name_list, value_list)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Sex')
plt.title('Average CA1 Firing Rate in Response to Natural Movies')
standard_error_movies_list_ca1=[standard_error_male_movies_ca1, standard_error_female_movies_ca1]
plt.errorbar(x=name_list, y=value_list, yerr=standard_error_movies_list_ca1, fmt='o', color='r', capsize=3)

# %%
#value_list = [ca3_female_mean, ca3_male_mean]
#name_list=['female','male']
#plt.bar(name_list, value_list)
#plt.ylabel('Average Firing Rate (Hz)')
#plt.xlabel('Sex')
#plt.title('Average CA3 Firing Rate in Response to Natural Scenes')
#standard_error_scenes_list_ca3=[standard_error_male_scenes_ca3, standard_error_female_scenes_ca3]
#plt.errorbar(x=name_list, y=value_list, yerr=standard_error_scenes_list_ca3, fmt='o', color='r', capsize=3)

value_listca3_1 = [ca3_female_mean, ca3_male_mean]
value_listca3_2 = [ca3_female_mean_movies, ca3_male_mean_movies]
name_listca3_1=['female scenes','male scenes']
name_listca3_2=['female movies','male movies']
x=np.arange(2)
width=0.40
plt.bar(x-0.2, value_listca3_1, width)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Stimulus')
plt.title('Average CA3 Firing Rate')

plt.xticks(x, ['scenes', 'movies'])
plt.bar(x+0.2, value_listca3_2, width)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Stimulus')
plt.title('Average CA3 Firing Rate')
standard_error_scenes_list_ca3=[standard_error_female_scenes_ca3, standard_error_male_scenes_ca3]
standard_error_movies_list_ca3=[standard_error_female_movies_ca3, standard_error_male_movies_ca3]
plt.errorbar(x-0.2, y=value_listca3_1, yerr=standard_error_scenes_list_ca3, fmt='o', color='r', capsize=3)
plt.errorbar(x+0.2, y=value_listca3_2, yerr=standard_error_movies_list_ca3, fmt='o', color='r', capsize=3)
#plt.legend(['female','male'], loc='upper right')
plt.legend(['female', 'male'], bbox_to_anchor =(1.5, 1.0), ncol = 1)

# %%
value_list = [ca3_female_mean_movies, ca3_male_mean_movies]
name_list=['female','male']
plt.bar(name_list, value_list)
plt.ylabel('Average Firing Rate (Hz)')
plt.xlabel('Sex')
plt.title('Average CA3 Firing Rate in Response to Natural Movies')
standard_error_movies_list_ca3=[standard_error_male_movies_ca3, standard_error_female_movies_ca3]
plt.errorbar(x=name_list, y=value_list, yerr=standard_error_movies_list_ca3, fmt='o', color='r', capsize=3)

# %% [markdown]
# ## Do an unpaired t-test for hippocampus regions for natural scenes and natural movies

# %%
from scipy import stats
dg_scenes_difference= dg_female_mean-dg_male_mean
print(f'difference of dg scenes means = {dg_scenes_difference:5.3f}')
n_dg_male_scenes=dg_male_scenes.shape[0]
n_dg_female_scenes=dg_female_scenes.shape[0]
print(f'dg male scenes n = {n_dg_male_scenes}, dg female scenes n = {n_dg_female_scenes}')
std_dg_male_scenes = dg_male_scenes.std(ddof=1)
std_dg_female_scenes = dg_female_scenes.std(ddof=1)
print(f'Standard deviations: {std_dg_male_scenes:5.3f} and {std_dg_female_scenes:5.3f}')
sed_dg_scenes = np.sqrt(std_dg_male_scenes**2 / n_dg_male_scenes + std_dg_female_scenes**2 / n_dg_female_scenes)
print(f'Standard error of the difference: {sed_dg_scenes:5.3f}')
upper_ci_dg_scenes = dg_scenes_difference + 2 * sed_dg_scenes
lower_ci_dg_scenes = dg_scenes_difference - 2 * sed_dg_scenes
print(f'Difference of the means = {dg_scenes_difference:5.3f} ({lower_ci_dg_scenes:5.3f} to {upper_ci_dg_scenes:5.3f})')
dg_scenes_statistic, dg_scenes_pvalue = stats.ttest_ind(dg_male_scenes, dg_female_scenes)
print(f'DG scenes Two-sample t-test: s = {dg_scenes_statistic:5.3f}, p = {dg_scenes_pvalue:5.3f}')
# Out:
# difference of dg scenes means = -2.316
# dg male scenes n = 4879, dg female scenes n = 3689
# Standard deviations: 8.556 and 8.542
# Standard error of the difference: 0.187
# Difference of the means = -2.316 (-2.689 to -1.943)
# DG scenes Two-sample t-test: s = 12.415, p = 0.000

# %%
dg_movies_difference= dg_female_mean_movies-dg_male_mean_movies
print(f'difference of dg movies means = {dg_movies_difference:5.3f}')
n_dg_male_movies=dg_male_movies.shape[0]
n_dg_female_movies=dg_female_movies.shape[0]
print(f'dg male movies n = {n_dg_male_movies}, dg female movies n = {n_dg_female_movies}')
std_dg_male_movies = dg_male_movies.std(ddof=1)
std_dg_female_movies = dg_female_movies.std(ddof=1)
print(f'Standard deviations: {std_dg_male_movies:5.3f} and {std_dg_female_movies:5.3f}')
sed_dg_movies = np.sqrt(std_dg_male_movies**2 / n_dg_male_movies + std_dg_female_movies**2 / n_dg_female_movies)
print(f'Standard error of the difference: {sed_dg_movies:5.3f}')
upper_ci_dg_movies = dg_movies_difference + 2 * sed_dg_movies
lower_ci_dg_movies = dg_movies_difference - 2 * sed_dg_movies
print(f'Difference of the means = {dg_movies_difference:5.3f} ({lower_ci_dg_movies:5.3f} to {upper_ci_dg_movies:5.3f})')
dg_movies_statistic, dg_movies_pvalue = stats.ttest_ind(dg_male_movies, dg_female_movies)
print(f'DG movies Two-sample t-test: s = {dg_movies_statistic:5.3f}, p = {dg_movies_pvalue:5.3f}')
# Out:
# difference of dg movies means = -2.398
# dg male movies n = 184500, dg female movies n = 139500
# Standard deviations: 9.739 and 9.442
# Standard error of the difference: 0.034
# Difference of the means = -2.398 (-2.466 to -2.330)
# DG movies Two-sample t-test: s = 70.326, p = 0.000

# %%
ca1_scenes_difference= ca1_female_mean-ca1_male_mean
print(f'difference of ca1 scenes means = {ca1_scenes_difference:5.3f}')
n_ca1_male_scenes=ca1_male_scenes.shape[0]
n_ca1_female_scenes=ca1_female_scenes.shape[0]
print(f'ca1 male scenes n = {n_ca1_male_scenes}, ca1 female scenes n = {n_ca1_female_scenes}')
std_ca1_male_scenes = ca1_male_scenes.std(ddof=1)
std_ca1_female_scenes = ca1_female_scenes.std(ddof=1)
print(f'Standard deviations: {std_ca1_male_scenes:5.3f} and {std_ca1_female_scenes:5.3f}')
sed_ca1_scenes = np.sqrt(std_ca1_male_scenes**2 / n_ca1_male_scenes + std_ca1_female_scenes**2 / n_ca1_female_scenes)
print(f'Standard error of the difference: {sed_ca1_scenes:5.3f}')
upper_ci_ca1_scenes = ca1_scenes_difference + 2 * sed_ca1_scenes
lower_ci_ca1_scenes = ca1_scenes_difference - 2 * sed_ca1_scenes
print(f'Difference of the means = {ca1_scenes_difference:5.3f} ({lower_ci_ca1_scenes:5.3f} to {upper_ci_ca1_scenes:5.3f})')
ca1_scenes_statistic, ca1_scenes_pvalue = stats.ttest_ind(ca1_male_scenes, ca1_female_scenes)
print(f'CA1 scenes Two-sample t-test: s = {ca1_scenes_statistic:5.3f}, p = {ca1_scenes_pvalue:5.3f}')
# Out:
# difference of ca1 scenes means = -4.464
# ca1 male scenes n = 8449, ca1 female scenes n = 8568
# Standard deviations: 8.231 and 6.072
# Standard error of the difference: 0.111
# Difference of the means = -4.464 (-4.686 to -4.241)
# CA1 scenes Two-sample t-test: s = 40.292, p = 0.000

# %%
ca1_movies_difference= ca1_female_mean_movies-ca1_male_mean_movies
print(f'difference of ca1 movies means = {ca1_movies_difference:5.3f}')
n_ca1_male_movies=ca1_male_movies.shape[0]
n_ca1_female_movies=ca1_female_movies.shape[0]
print(f'ca1 male movies n = {n_ca1_male_movies}, ca1 female movies n = {n_ca1_female_movies}')
std_ca1_male_movies = ca1_male_movies.std(ddof=1)
std_ca1_female_movies = ca1_female_movies.std(ddof=1)
print(f'Standard deviations: {std_ca1_male_movies:5.3f} and {std_ca1_female_movies:5.3f}')
sed_ca1_movies = np.sqrt(std_ca1_male_movies**2 / n_ca1_male_movies + std_ca1_female_movies**2 / n_ca1_female_movies)
print(f'Standard error of the difference: {sed_ca1_movies:5.3f}')
upper_ci_ca1_movies = ca1_movies_difference + 2 * sed_ca1_movies
lower_ci_ca1_movies = ca1_movies_difference - 2 * sed_ca1_movies
print(f'Difference of the means = {ca1_scenes_difference:5.3f} ({lower_ci_ca1_scenes:5.3f} to {upper_ci_ca1_scenes:5.3f})')
ca1_movies_statistic, ca1_movies_pvalue = stats.ttest_ind(ca1_male_movies, ca1_female_movies)
print(f'CA1 movies Two-sample t-test: s = {ca1_movies_statistic:5.3f}, p = {ca1_movies_pvalue:5.3f}')
# Out:
# difference of ca1 movies means = -3.297
# ca1 male movies n = 319500, ca1 female movies n = 324000
# Standard deviations: 10.978 and 8.968
# Standard error of the difference: 0.025
# Difference of the means = -4.464 (-4.686 to -4.241)
# CA1 movies Two-sample t-test: s = 132.015, p = 0.000

# %%
ca3_scenes_difference= ca3_male_mean-ca3_female_mean
print(f'difference of ca3 scenes means = {ca3_scenes_difference:5.3f}')
n_ca3_male_scenes=ca3_male_scenes.shape[0]
n_ca3_female_scenes=ca3_female_scenes.shape[0]
print(f'ca3 male scenes n = {n_ca3_male_scenes}, ca3 female scenes n = {n_ca3_female_scenes}')
std_ca3_male_scenes = ca3_male_scenes.std(ddof=1)
std_ca3_female_scenes = ca3_female_scenes.std(ddof=1)
print(f'Standard deviations: {std_ca3_male_scenes:5.3f} and {std_ca3_female_scenes:5.3f}')
sed_ca3_scenes = np.sqrt(std_ca3_male_scenes**2 / n_ca3_male_scenes + std_ca3_female_scenes**2 / n_ca3_female_scenes)
print(f'Standard error of the difference: {sed_ca3_scenes:5.3f}')
upper_ci_ca3_scenes = ca3_scenes_difference + 2 * sed_ca3_scenes
lower_ci_ca3_scenes = ca3_scenes_difference - 2 * sed_ca3_scenes
print(f'Difference of the means = {ca3_scenes_difference:5.3f} ({lower_ci_ca3_scenes:5.3f} to {upper_ci_ca3_scenes:5.3f})')
ca3_scenes_statistic, ca3_scenes_pvalue = stats.ttest_ind(ca3_male_scenes, ca3_female_scenes)
print(f'CA3 scenes Two-sample t-test: s = {ca3_scenes_statistic:5.3f}, p = {ca3_scenes_pvalue:5.3f}')
# Out:
# difference of ca3 scenes means = -2.903
# ca3 male scenes n = 1190, ca3 female scenes n = 1785
# Standard deviations: 5.923 and 10.999
# Standard error of the difference: 0.312
# Difference of the means = -2.903 (-3.527 to -2.279)
# CA3 scenes Two-sample t-test: s = -8.335, p = 0.000

# %%
ca3_movies_difference= ca3_male_mean_movies-ca3_female_mean_movies
print(f'difference of ca3 movies means = {ca3_movies_difference:5.3f}')
n_ca3_male_movies=ca3_male_movies.shape[0]
n_ca3_female_movies=ca3_female_movies.shape[0]
print(f'ca3 male movies n = {n_ca3_male_movies}, ca3 female movies n = {n_ca3_female_movies}')
std_ca3_male_movies = ca3_male_movies.std(ddof=1)
std_ca3_female_movies = ca3_female_movies.std(ddof=1)
print(f'Standard deviations: {std_ca3_male_movies:5.3f} and {std_ca3_female_movies:5.3f}')
sed_ca3_movies = np.sqrt(std_ca3_male_movies**2 / n_ca3_male_movies + std_ca3_female_movies**2 / n_ca3_female_movies)
print(f'Standard error of the difference: {sed_ca3_movies:5.3f}')
upper_ci_ca3_movies = ca3_movies_difference + 2 * sed_ca3_movies
lower_ci_ca3_movies = ca3_movies_difference - 2 * sed_ca3_movies
print(f'Difference of the means = {ca3_scenes_difference:5.3f} ({lower_ci_ca3_scenes:5.3f} to {upper_ci_ca3_scenes:5.3f})')
ca3_movies_statistic, ca3_movies_pvalue = stats.ttest_ind(ca3_male_movies, ca3_female_movies)
print(f'CA3 movies Two-sample t-test: s = {ca3_movies_statistic:5.3f}, p = {ca3_movies_pvalue:5.3f}')
# Out:
# difference of ca3 movies means = -4.713
# ca3 male movies n = 45000, ca3 female movies n = 67500
# Standard deviations: 6.770 and 11.419
# Standard error of the difference: 0.054
# Difference of the means = -2.903 (-3.527 to -2.279)
# CA3 movies Two-sample t-test: s = -78.817, p = 0.000

# %% [markdown]
# ### Run an ANOVA

# %%
import seaborn as sns

import pandas as pdimport statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

N=len(ca3_male_movies.len)
print(N)

# %% [markdown]
# ### If working with Visual Coding: 2P Ca2+ Imaging Data use the following code block to import the cache object and point it to the data already downloaded and stored on LongLeaf.  Do not change this code.

# %%
#this code block should only be run if you are working with the brain observatory Ca2+ imaging data
from allensdk.core.brain_observatory_cache import BrainObservatoryCache

drive_path = '/overflow/NSCI274/projects/BrainObservatoryOPhysData/'

manifest_file = os.path.join(drive_path,'manifest.json')

boc = BrainObservatoryCache(manifest_file=manifest_file)

# %% [markdown]
# ### If working with Visual Behavior: 2P Ca2+ Imaging Data use the following code block to import the cache object and point it to the data already downloaded and stored on LongLeaf.  Do not change this code.

# %%
#this code block should only be run if you are working with the visual behavior Ca2+ imaging data
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache

data_storage_directory = Path("/overflow/NSCI274/projects/ophysdata")

cache = VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=data_storage_directory)

# %% [markdown]
# ## Resources:
#
#
# ### Sample Allen Jupyter Notebooks to get started:
# https://allensdk.readthedocs.io/en/latest/visual_behavior_optical_physiology.html
# https://allensdk.readthedocs.io/en/latest/visual_coding_neuropixels.html
#
#
# Insert text.
